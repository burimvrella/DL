# %%
import os
import glob

latest_versions = {}

os.chdir("../Raw_data_testing")

pdf_files = glob.glob("*.pdf")

for pdf_file in pdf_files:
    base_filename = pdf_file[:-6] 

    version_number = int(pdf_file[-5]) 

    if base_filename not in latest_versions or version_number > latest_versions[base_filename]:
        latest_versions[base_filename] = version_number

for pdf_file in pdf_files:
    base_filename = pdf_file[:-6]
    version_number = int(pdf_file[-5])

    if version_number < latest_versions[base_filename]:
        os.remove(pdf_file)
        print(f"Deleted old version: {pdf_file}")

# %%
import os
import glob
import PyPDF2
import json

import re

def extract_references_content(text):
    
    pattern = r'R\s*E\s*F\s*E\s*R\s*E\s*N\s*C\s*E\s*S(.+)'

    
    match = re.search(pattern, text, re.DOTALL | re.IGNORECASE)

    
    if match:
        
        return match.group(1).strip()
    else:
        return None

def extract_references(text):
    
    references_content = extract_references_content(text)

    
    if references_content:
        
        pattern = r'\[\d+\]\s*([^“]+?)“([^”]+)”'

        
        matches = re.findall(pattern, references_content, re.DOTALL)

        
        cleaned_matches = []
        for authors, title in matches:
            
            authors_list = [author.strip().replace(',', '') for author in authors.split(',')]

            
            authors_list = [author.replace(' and ', ' ').replace(' et al.', '') for author in authors_list]

            
            authors_list = list(filter(None, authors_list))

            
            cleaned_title = title.replace('\n', '').rstrip(',')

            cleaned_matches.append({'authors': authors_list, 'title': cleaned_title.strip()})

        return cleaned_matches
    else:
        return None

def extract_information(pdf_file):
    
    with open(pdf_file, 'rb') as file:
        
        pdf_reader = PyPDF2.PdfReader(file)

        
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            try:
                text = page.extract_text()
            except:
                return None

            
            references = extract_references(text)

        
        file.close()
        return references

def process_remaining_pdfs(raw_data_folder, json_file_path):
    
    pdf_metadata_dict = {}

    
    with open(json_file_path, 'r', encoding='utf-8') as json_file:
        for line in json_file:
            
            try:
                data = json.loads(line)
            except json.JSONDecodeError:
                print("Error decoding JSON:", line)
                continue  

            
            pdf_id = data.get('id', '')
            if not pdf_id.startswith("2003"):
                continue  

            
            pdf_filename = pdf_id + ".pdf"

            
            title, authors_parsed, doi = extract_metadata_from_json(data)

            
            pdf_metadata_dict[pdf_filename] = {
                'title': title,
                'authors': authors_parsed,
                'doi': doi
            }

    
    os.chdir(raw_data_folder)

    
    pdf_files = glob.glob("*.pdf")

    result_dict = {}

    
    for pdf_file in pdf_files:
        
        pdf_filename = os.path.splitext(pdf_file)[0][:-2]+".pdf"

        
        if pdf_filename in pdf_metadata_dict:
            
            references = extract_information(pdf_file)

            metadata = pdf_metadata_dict[pdf_filename]
            metadata['references'] = references
            result_dict[pdf_filename] = metadata    
            
    return result_dict
    

def extract_metadata_from_json(data):
    
    title = data.get('title', '')
    authors_parsed = data.get('authors_parsed', [])
    doi = data.get('doi', '')

    authors_parsed = [f"{author[1]} {author[0]}" if len(author) > 1 else author[0] for author in authors_parsed]

    return title, authors_parsed, doi


raw_data_folder = "../Raw_data_testing"


json_file_path = "../arxiv_metadata_dump/arxiv-metadata-oai-snapshot.json"


data_dict = process_remaining_pdfs(raw_data_folder, json_file_path)
# Out:
# FloatObject (b'0.000-167979') invalid; use 0.0 instead

# %%
for key, value in data_dict.items():
    print(key, ":", value)
# Out:
# 2003.01609.pdf : {'title': 'SELD-TCN: Sound Event Localization & Detection via Temporal\n  Convolutional Networks', 'authors': ['Karim Guirguis', 'Christoph Schorn', 'Andre Guntoro', 'Sherif Abdulatif', 'Bin Yang'], 'doi': '10.23919/Eusipco47968.2020.9287716', 'references': [{'authors': ['T. Marques', 'L. Thomas', 'S. Martin', 'D. Mellinger', 'J. A Ward', 'D. Moretti', 'D. Harris', 'and P. Tyack'], 'title': 'Estimating animal population density usingpassive acoustics'}, {'authors': ['E. Benetos T. Weyde'], 'title': 'An Efﬁcient Temporally-Constrained Proba-bilistic Model for Multiple-Instrument Music Transcription'}, {'authors': ['T. Heittola', 'A. Klapuri', 'and T. Virtanen'], 'title': 'Musical Instrument Recog-nition in Polyphonic Audio Using Source-Filter Model for SoundSeparation.'}, {'authors': ['D. Rossiter', 'G. Lam', 'and B. Mak'], 'title': 'Automatic Audio Indexing and AudioPlayback Speed Control as Tools for Language Learning'}, {'authors': ['R. Roden', 'S. Gerlach', 'N. Moritz', 'S. Weinzierl', 'and S. Goetze'], 'title': 'On soundsource localization of speech signals using deep neural networks'}, {'authors': ['X. Xiao', 'S. Zhao', 'X. Zhong', 'D. Jones', 'E. Chng', 'and H. Li'], 'title': 'A learning-based approach to direction of arrival estimation in noisy and reverberantenvironments'}, {'authors': ['R. Takeda K. Komatani'], 'title': 'Discriminative multiple sound sourcelocalization based on deep neural networks using independent locationmodel'}, {'authors': ['A. Nugraha', 'A. Liutkus', 'and E. Vincent', 'Deep Neural Network Based\nMultichannel Audio Source Separation', 'Jan. 2017.\n[9] F. Vesperini', 'P. Vecchiotti', 'E. Principi', 'S. Squartini', 'and F. Piazza'], 'title': 'Aneural network based algorithm for speaker localization in a multi-roomenvironment'}, {'authors': ['S. Chakrabarty E. Habets'], 'title': 'Broadband DOA estimation usingconvolutional neural networks trained with noise signals'}, {'authors': ['S. Adavanne', 'A. Politis', 'and T. Virtanen'], 'title': 'Direction of Arrival Estima-tion for Multiple Sound Sources Using Convolutional Recurrent NeuralNetwork'}, {'authors': ['J. Schrder', 'B. Cauchi', 'M. Schdler', 'N. Moritz', 'K. Adiloglu', 'J. Anemller', 'S. Doclo', 'B. Kollmeier', 'and S. Goetze'], 'title': 'Acoustic event detection usingsignal enhancement and spectro-temporal feature extraction'}, {'authors': ['T. Heittola', 'A. Mesaros', 'A. Eronen', 'and T. Virtanen'], 'title': 'Context-dependentsound event detection'}, {'authors': ['T. Heittola', 'A. Mesaros', 'T. Virtanen', 'and A. Eronen'], 'title': 'Sound EventDetection in Multisource Environments Using Source Separation'}, {'authors': ['S. Innami H. Kasai'], 'title': 'NMF-based environmental sound source sep-aration using time-variant gain features'}, {'authors': ['A. Dessein', 'A. Cont', 'and G. Lemaitre'], 'title': 'Real-Time Detection of Over-lapping Sound Events with Non-Negative Matrix Factorization'}, {'authors': ['T. Komatsu', 'T. Toizumi', 'R. Kondo', 'and Y . Senda'], 'title': 'Acoustic EventDetection Method Using Semi-Supervised Non-Negative Matrix Fac-torization with Mixtures of Local Dictionaries'}, {'authors': ['H. Zhang', 'I. Mcloughlin', 'and Y . Song'], 'title': 'Robust sound event recognitionusing convolutional neural networks'}, {'authors': ['H. Phan', 'L. Hertel', 'M. Maa', 'and A. Mertins'], 'title': 'Robust Audio EventRecognition with 1-Max Pooling Convolutional Neural Networks'}, {'authors': ['P. Zinemanas', 'P. Cancela', 'and M. Rocamora'], 'title': 'End-to-end ConvolutionalNeural Networks for Sound Event Detection in Urban Environments'}, {'authors': ['S. Adavanne', 'G. Parascandolo', 'P. Pertil', 'T. Heittola', 'and T. Virtanen'], 'title': 'Sound Event Detection in Multichannel Audio Using Spatial andHarmonic Features'}, {'authors': ['T. Hayashi', 'S. Watanabe', 'T. Toda', 'T. Hori', 'J. Le Roux', 'and K. Takeda'], 'title': 'Duration-Controlled LSTM for Polyphonic Sound Event Detection'}, {'authors': ['M. Zhrer F.  ...
# 2003.01774.pdf : {'title': 'Directional Compliance in Obstacle-Aided Navigation for Snake Robots', 'authors': ['Tianyu Wang', 'Julian Whitman', 'Matthew Travers', 'Howie Choset'], 'doi': '10.23919/ACC45564.2020.9148021', 'references': [{'authors': ['T. Kano', 'R. Yoshizawa', 'and A. Ishiguro'], 'title': 'Tegotae-based decentralisedcontrol scheme for autonomous gait transition of snake-like robots'}, {'authors': ['F. Sanﬁlippo', 'J. Azpiazu', 'G. Maraﬁoti', 'A. Transeth', 'Ø. Stavdahl', 'and P. Liljeb ¨ack'], 'title': 'Perception-driven obstacle-aided locomotion forsnake robots: the state of the art, challenges and possibilities'}, {'authors': ['M. Travers', 'J. Whitman', 'and H. Choset'], 'title': 'Shape-based coordination inlocomotion control'}, {'authors': ['J. Whitman', 'F. Ruscelli', 'M. Travers', 'and H. Choset'], 'title': 'Shape-basedcompliant control with variable coordination centralization on a snakerobot'}, {'authors': ['B. C. Jayne'], 'title': 'Muscular mechanisms of snake locomotion: an elec-tromyographic study of lateral undulation of the ﬂorida banded watersnake (nerodia fasciata) and the yellow rat snake (elaphe obsoleta)'}, {'authors': ['P. E. Schiebel', 'J. M. Rieser', 'A. M. Hubbard', 'L. Chen', 'D. Z. Rocklin', 'and D. I. Goldman'], 'title': 'Mechanical diffraction reveals the role of passivedynamics in a slithering snake'}, {'authors': ['H. Astley', 'J. Mendelson', 'and D. Goldman'], 'title': 'Side-Impact Collision:Obstacle Negotiation Mechanics in Sidewinding Snakes'}, {'authors': ['M. Travers', 'A. Ansari', 'and H. Choset'], 'title': 'A dynamical systems approachto obstacle navigation for a series-elastic hexapod robot'}, {'authors': ['S. Hirose'], 'title': 'Biologically inspired robots'}, {'authors': ['M. Tesch', 'K. Lipkin', 'I. Brown', 'R. Hatton', 'A. Peck', 'J. Rembisz', 'and H. Choset'], 'title': 'Parameterized and scripted gaits for modular snakerobots'}, {'authors': ['C. Ott', 'R. Mukherjee', 'and Y . Nakamura'], 'title': 'Uniﬁed impedance and ad-mittance control'}, {'authors': ['D. Rollinson', 'Y . Bilgen', 'B. Brown', 'F. Enner', 'S. Ford', 'C. Layton', 'J. Rembisz', 'M. Schwerin', 'A. Willig', 'P. Velagapudi', 'et al.'], 'title': 'Designand architecture of a series elastic snake robot'}, {'authors': ['G. A. Pratt M. M. Williamson'], 'title': 'Series elastic actuators'}]}
# 2003.01000.pdf : {'title': 'Robust Policy Search for Robot Navigation with Stochastic Meta-Policies', 'authors': ['Javier Garcia-Barcos', 'Ruben Martinez-Cantin'], 'doi': None, 'references': [{'authors': ['R. J. Williams'], 'title': 'Simple statistical gradient-following algorithms forconnectionist reinforcement learning'}, {'authors': ['M. Deisenroth', 'G. Neumann', 'and J. Peters'], 'title': 'A survey on policy searchfor robotics'}, {'authors': ['J. Peters S. Schaal'], 'title': 'Policy gradient methods for robotics'}, {'authors': ['N. Kohl P. Stone'], 'title': 'Policy gradient reinforcement learning for fastquadrupedal locomotion'}, {'authors': ['S. Levine P. Abbeel'], 'title': 'Learning neural network policies withguided policy search under unknown dynamics'}, {'authors': ['R. Martinez-Cantin', 'N. de Freitas', 'A. Doucet', 'and J. A. Castellanos'], 'title': 'Active policy learning for robot planning and exploration underuncertainty'}, {'authors': ['R. Martinez-Cantin', 'N. de Freitas', 'E. Brochu', 'J. Castellanos', 'and\nA. Doucet'], 'title': 'A Bayesian exploration-exploitation approach for optimalonline sensing and planning with a visually guided mobile robot.'}, {'authors': ['B. Shahriari', 'K. Swersky', 'Z. Wang', 'R. Adams', 'and N. de Freitas'], 'title': 'Taking the human out of the loop: A review of Bayesian optimization'}, {'authors': ['D. Lizotte', 'T. Wang', 'M. Bowling', 'and D. Schuurmans.'], 'title': 'Automaticgait optimization with gaussian process regression'}, {'authors': ['R. Calandra', 'A. Seyfarth', 'J. Peters', 'and M. Deisenroth'], 'title': 'Bayesian opti-mization for learning gaits under uncertainty'}, {'authors': ['A. Rai', 'R. Antonova', 'F. Meier', 'and C. G. Atkeson'], 'title': 'Using simulation toimprove sample-efﬁciency of bayesian optimization for bipedal robots.'}, {'authors': ['M. Tesch', 'J. Schneider', 'and H. Choset'], 'title': 'Adapting control policiesfor expensive systems to changing environments'}, {'authors': ['S. R. Kuindersma', 'R. A. Grupen', 'and A. G. Barto'], 'title': 'Variable risk controlvia stochastic optimization'}, {'authors': ['R. Marchant F. Ramos'], 'title': 'Bayesian optimisation for informativecontinuous path planning'}, {'authors': ['J. Nogueira', 'R. Martinez-Cantin', 'A. Bernardino', 'and L. Jamone'], 'title': 'Unscented bayesian optimization for safe robot grasping'}, {'authors': ['C. Daniel', 'O. Kroemer', 'M. Viering', 'J. Metz', 'and J. Peters'], 'title': 'Activereward learning with a novel acquisition function'}, {'authors': ['A. Cully', 'J. Clune', 'D. Tarapore', 'and J. B. Mouret'], 'title': 'Robots that canadapt like animals'}, {'authors': ['D. R. Jones', 'M. Schonlau', 'and W. J. Welch'], 'title': 'Efﬁcient globaloptimization of expensive black-box functions'}, {'authors': ['Y . Sui', 'A. Gotovos', 'J. Burdick', 'and A. Krause'], 'title': 'Safe exploration foroptimization with gaussian processes'}, {'authors': ['R. Martinez-Cantin', 'K. Tee', 'and M. McCourt'], 'title': 'Practical bayesianoptimization in the presence of outliers'}, {'authors': ['R. Martinez-Cantin'], 'title': 'Bayesian optimization with adaptive kernels forrobot control'}, {'authors': ['J. Garcia-Barcos R. Martinez-Cantin'], 'title': 'Fully distributed bayesianoptimization with stochastic policies'}, {'authors': ['R. Martinez-Cantin'], 'title': 'Funneled Bayesian optimization for design, tuningand control of autonomous systems'}, {'authors': ['D. Huang', 'T. T. Allen', 'W. I. Notz', 'and N. Zheng'], 'title': 'Global optimizationof stochastic black-box systems via sequential kriging meta-models'}, {'authors': ['J. Mockus', 'V . Tiesis', 'and A. Zilinskas'], 'title': 'The application of Bayesianmethods for seeking the extremum'}, {'authors': ['C. Rasmussen C. Williams', 'Gaussian Processes for Machine\nLearning . The MIT Press', '2006.\n[27] J. Snoek', 'H. Larochelle', 'and R. Adams'], 'title': 'Practical Bayesian optimiza-tion of machine learning algorithms'}, {'authors': ['A. D. Bull'], 't ...
# 2003.00598.pdf : {'title': 'Data Normalization for Bilinear Structures in High-Frequency Financial\n  Time-series', 'authors': ['Dat Thanh Tran', 'Juho Kanniainen', 'Moncef Gabbouj', 'Alexandros Iosifidis'], 'doi': None, 'references': [{'authors': ['D. T. Tran', 'A. Iosiﬁdis', 'J. Kanniainen', 'and M. Gabbouj'], 'title': 'T empo-ral attention-augmented bilinear network for ﬁnancial tim e-series dataanalysis'}, {'authors': ['Z. Zhang', 'S. Zohren', 'and S. Roberts'], 'title': 'Deeplob: Deep convo lutionalneural networks for limit order books'}, {'authors': ['N. Passalis', 'A. Tefas', 'J. Kanniainen', 'M. Gabbouj', 'and A. I osiﬁdis'], 'title': 'Temporal bag-of-features learning for predicting mid pri ce movementsusing high frequency limit order book data'}, {'authors': ['D. T. Tran', 'M. Gabbouj', 'and A. Iosiﬁdis'], 'title': 'Multilinear cla ss-speciﬁcdiscriminant analysis'}, {'authors': ['D. T. Tran', 'M. Magris', 'J. Kanniainen', 'M. Gabbouj', 'and A. Io siﬁdis'], 'title': 'Tensor representation in high-frequency ﬁnancial data fo r price changeprediction'}, {'authors': ['N. Passalis', 'A. Tsantekidis', 'A. Tefas', 'J. Kanniainen', 'M. Gabbouj', 'and\nA. Iosiﬁdis'], 'title': 'Time-series classiﬁcation using neural bag- of-features'}, {'authors': ['S. Ren', 'K. He', 'R. Girshick', 'and J. Sun'], 'title': 'Faster r-cnn: Towa rds real-timeobject detection with region proposal networks'}, {'authors': ['J. Redmon', 'S. Divvala', 'R. Girshick', 'and A. Farhadi'], 'title': 'You o nly lookonce: Uniﬁed, real-time object detection'}, {'authors': ['A. Iosiﬁdis', 'A. Tefas', 'and I. Pitas'], 'title': 'View-invariant act ion recognitionbased on artiﬁcial neural networks'}, {'authors': ['D. T. Tran', 'A. Iosiﬁdis', 'and M. Gabbouj'], 'title': 'Improving efﬁc iency inconvolutional neural networks with multilinear ﬁlters'}, {'authors': ['D. T. Tran', 'M. Yamac', 'A. Degerli', 'M. Gabbouj', 'and A. Iosiﬁ dis'], 'title': 'Multilinear compressive learning'}, {'authors': ['D. T. Tran', 'M. Gabbouj', 'and A. Iosiﬁdis'], 'title': 'Multilinear co mpressivelearning with prior knowledge'}, {'authors': ['D. Bahdanau', 'K. Cho', 'and Y . Bengio'], 'title': 'Neural machine tran slation byjointly learning to align and translate'}, {'authors': ['J. Devlin', 'M.-W. Chang', 'K. Lee', 'and K. Toutanova'], 'title': 'Bert: Pre-trainingof deep bidirectional transformers for language understan ding'}, {'authors': ['X. Shao'], 'title': 'Self-normalization for time series: a review of recent de-velopments'}, {'authors': ['S. Nayak', 'B. B. Misra', 'and H. S. Behera'], 'title': 'Impact of data no rmalizationon stock index forecasting'}, {'authors': ['A. Ntakaris', 'G. Mirone', 'J. Kanniainen', 'M. Gabbouj', 'and A . Iosiﬁdis'], 'title': 'Feature engineering for mid-price prediction with deep le arning'}, {'authors': ['S. Ioffe C. Szegedy'], 'title': 'Batch normalization: Acceler ating deepnetwork training by reducing internal covariate shift'}, {'authors': ['D. Ulyanov', 'A. Vedaldi', 'and V . Lempitsky'], 'title': 'Instance nor malization: Themissing ingredient for fast stylization'}, {'authors': ['N. Passalis', 'A. Tefas', 'J. Kanniainen', 'M. Gabbouj', 'and A. Iosiﬁdis'], 'title': 'Deepadaptive input normalization for price forecasting using l imit order bookdata'}, {'authors': ['X. Glorot Y . Bengio'], 'title': 'Understanding the difﬁculty o f trainingdeep feedforward neural networks'}, {'authors': ['K. He', 'X. Zhang', 'S. Ren', 'and J. Sun'], 'title': 'Delving deep into rec tiﬁers:Surpassing human-level performance on imagenet classiﬁca tion'}, {'authors': ['A. Ntakaris', 'M. Magris', 'J. Kanniainen', 'M. Gabbouj', 'and A . Iosiﬁdis'], 'title': 'Benchmark dataset for mid-price forecasting of limit orde r book datawith machine learning methods'}, {'authors': ['D. T. Tran', 'J. Kanniainen', 'M. Gabbouj', 'and A. Iosiﬁdis'], 'title': 'Data-drivenneural architecture learning for ﬁnancial time-series for ecasting'}, {'authors': ['A. Tsantekidis', 'N. Passalis', 'A ...
# 2003.00386.pdf : {'title': 'Experimental Evaluation of a Pseudo-Doppler Direction-Finding System for\n  Localizing Radio Tags', 'authors': ['William E. Gerhard', 'Pratap Tokekar'], 'doi': None, 'references': [{'authors': ['J. Linchant', 'J. Lisein', 'J. Semeki', 'P. Lejeune', 'and C. Vermeulen'], 'title': 'Areunmanned aircraft systems (uass) the future of wildlife monitoring? areview of accomplishments and challenges'}, {'authors': ['K. V onehr', 'S. Hilaski', 'B. E. Dunne', 'and J. Ward'], 'title': 'Software deﬁnedradio for direction-ﬁnding in uav wildlife tracking'}, {'authors': ['H. Bayram', 'N. Stefas', 'K. S. Engin', 'and V . Isler'], 'title': 'Tracking wildlifewith multiple uavs: System design, safety and ﬁeld experiments'}, {'authors': ['H. Bayram', 'N. Stefas', 'and V . Isler'], 'title': 'Aerial radio-based telemetryfor tracking wildlife'}, {'authors': ['V . Isler', 'N. Noori', 'P. Plonski', 'A. Renzaglia', 'P. Tokekar', 'and J. Van-\nder Hook'], 'title': 'Finding and tracking targets in the wild: Algorithms andﬁeld deployments'}, {'authors': ['J. Vander Hook', 'P. Tokekar', 'and V . Isler'], 'title': 'Cautious greedy strategyfor bearing-based active localization: Experiments and theoreticalanalysis'}, {'authors': ['P. Tokekar', 'E. Branson', 'J. Vander Hook', 'and V . Isler'], 'title': 'Trackingaquatic invaders: Autonomous robots for monitoring invasive ﬁsh'}, {'authors': ['H. Bayram', 'K. Doddapaneni', 'N. Stefas', 'and V . Isler'], 'title': 'Active lo-calization of vhf collared animals with aerial robots'}, {'authors': ['A. Desrochers', 'J. Tremblay', 'Y . Aubry', 'D. Chabot', 'P. Pace', 'and D. Bird'], 'title': 'Estimating wildlife tag location errors from a vhf receiver mountedon a drone'}, {'authors': ['R. B. MacCurdy', 'R. M. Gabrielson', 'and K. A. Cortopassi'], 'title': 'Automatedwildlife radio tracking'}, {'authors': [], 'title': 'Doppler df instruments : More picodopp df information'}, {'authors': [], 'title': 'Introduction into theory of direction ﬁnding'}, {'authors': [], 'title': 'Hackrf one - great scott gadgets'}, {'authors': [], 'title': 'Opera cake mossmann/hackrf wiki'}, {'authors': ['J. Moell'], 'title': 'Wide-range antenna arrays for the roanoke doppler'}, {'authors': ['A. M ˚arell', 'J. P. Ball', 'and A. Hofgaard'], 'title': 'Foraging and movement pathsof female reindeer: insights from fractal analysis, correlated randomwalks, and l ´evy ﬂights'}, {'authors': ['S. Benhamou'], 'title': 'How many animals really do the l ´evy walk?'}, {'authors': ['F. Bartumeus', 'M. G. E. da Luz', 'G. M. Viswanathan', 'and J. Cata-\nlan'], 'title': 'Animal search strategies: a quantitative random-walk analysis'}, {'authors': ['A. M. Johansen'], 'title': 'Smctc: Sequential monte carlo in c++'}, {'authors': ['J. S. Liu R. Chen'], 'title': 'Sequential monte carlo methods for dynamicsystems'}, {'authors': ['A. Torabi', 'M. W. Shafer', 'G. S. Vega', 'and K. M. Rothfus'], 'title': 'Uav-rt:An sdr based aerial platform for wildlife tracking'}]}
# 2003.01306.pdf : {'title': 'Machine Learning Empowered Beam Management for Intelligent Reflecting\n  Surface Assisted MmWave Networks', 'authors': ['Chenglu Jia', 'Hui Gao', 'Na Chen', 'Yuan He'], 'doi': None, 'references': [{'authors': ['T. S. Rappaport', 'S. Sun', 'R. Mayzus', 'H. Zhao', 'Y . Azar', 'K. Wang', 'G. N.\nWong', 'J. K. Schulz', 'M. Samimi', 'and F. Gutierrez'], 'title': 'Millimeter wavemobile communications for 5G cellular: It will work!'}, {'authors': ['M. Giordani', 'M. Polese', 'A. Roy', 'D. Castor', 'and M. Zorzi'], 'title': 'A tutorialon beam management for 3GPP NR at mmwave frequencies'}, {'authors': ['Q. Wu R. Zhang'], 'title': 'Intelligent reﬂecting surface enhanced wirelessnetwork: Joint active and passive beamforming design'}, {'authors': ['C. Huang', 'S. Hu', 'G. Alexandropoulos', 'A. Zappone', 'C. Yuen', 'R. Zhang', 'M. D. Renzo', 'and M. Debbah'], 'title': 'Holographic MIMO surfaces for 6Gwireless networks: Opportunities, challenges, and trends'}, {'authors': ['C. Huang', 'A. Zappone', 'G. Alexandropoulos', 'M. Debbah', 'and C. Yuen'], 'title': 'Reconﬁgurable intelligent surfaces for energy efﬁciency in wirelesscommunication'}, {'authors': ['P. Wang', 'J. Fang', 'X. Yuan', 'Z. Chen', 'H. Duan', 'and H. Li'], 'title': 'Intelligentreﬂecting surface-assisted millimeter wave communications: Joint activeand passive precoding design'}, {'authors': ['G. Zheng', 'C. Hua', 'R. Zheng', 'and Q. Wang'], 'title': 'Toward robust relayplacement in 60 GHz mmwave wireless personal area networks withdirectional antenna'}, {'authors': ['O. Eng', 'J. Kneckt', 'O. Alanen', 'Z. Chang', 'T. Huovinen', 'and T. Nihtil?'], 'title': 'IEEE 802.11ac: Enhancements for very high throughput WLANs'}, {'authors': ['D. De Donno', 'J. Palacios', 'and J. Widmer'], 'title': 'Millimeter-wave beamtraining acceleration through low-complexity hybrid transceivers'}, {'authors': ['J. Aviles A. Kouki'], 'title': 'Position-aided mm-wave beam training underNLOS conditions'}, {'authors': ['V . Va', 'T. Shimizu', 'G. Bansal', 'and R. Heath'], 'title': 'Online learning forposition-aided millimeter wave beam training'}, {'authors': ['S. Jayaprakasam', 'X. Ma', 'J. Choi', 'and S. Kim'], 'title': 'Robust beam-trackingfor mmWave mobile communications'}, {'authors': ['D. Zhu', 'J. Choi', 'Q. Cheng', 'W. Xiao', 'and R. Heath'], 'title': 'High-resolutionangle tracking for mobile wideband millimeter-wave systems withantenna array calibration'}, {'authors': ['J. Zhang', 'W. Xu', 'H. Gao', 'M. Pan', 'Z. Feng', 'and Z. Han'], 'title': 'Position-attitudeprediction based beam tracking for UA V mmWave communications'}, {'authors': ['A. Taha', 'M. Alrabeiah', 'and A. Alkhateeb'], 'title': 'Enabling large intelligentsurfaces with compressive sensing and deep learning'}, {'authors': ['W. Liu Z. Wang'], 'title': 'Statistics-assisted beam training for mmwavemassive MIMO systems'}, {'authors': ['N. Gonz ´alez-Prelcic', 'A. Ali', 'V . Va', 'and R. Heath'], 'title': 'Millimeter-wavecommunication with out-of-band information'}, {'authors': ['M. D. Renzo et al'], 'title': 'Smart radio environments empowered by recon-ﬁgurable AI meta-surfaces: an idea whose time has come'}, {'authors': ['W. Xu', 'Y . Xu', 'C. Lee', 'Z. Feng', 'P. Zhang', 'and J. Lin'], 'title': 'Data-cognition-empowered intelligent wireless networks: Data, utilities, cognition brain,and architecture'}]}
# 2003.01107.pdf : {'title': 'Reconfigurable Parallel Architecture of High Speed Round Robin Arbiter', 'authors': ['Arnab Paul', 'Mamdudul Haque Khan', 'M. Muktadir Rahman', 'Tanvir Zaman Khan', 'Prajoy Podder', 'Md. Yeasir Akram Khan'], 'doi': '10.1109/EESCO.2015.7253744', 'references': [{'authors': ['E. S. Shin', 'V. J. Mooney  G. F. Riley'], 'title': 'Round -robin Arbiter Design and Generation'}, {'authors': ['M. Abdelrasoul', 'M. Ragab V. Goulart'], 'title': "Impact of Round Robin Arbiters on router's performance for NoCs on FPGAs"}, {'authors': ['Stephen Brown Zvonko Vranesic book'], 'title': 'Fundamentals of Digital Logic with Verilog Design'}, {'authors': ['Yong jian Li', 'Naiju Zeng', 'W. N. N. Hung Xiaoyu Song'], 'title': 'Enhanced symbolic simulation of a round -robin arbiter'}, {'authors': ['Si Qing Zheng Mei Yang'], 'title': 'Algorithm -Hardware Codesign of  Fast Parallel Round -Robin Arbiters'}, {'authors': ['S. Q. Zheng', 'Mei Yang', 'J. Blanton P. Golla'], 'title': 'A simple and fast parallel round -robin arbiter for high -speed switch control and sched uling'}, {'authors': ['Matt Weber'], 'title': 'Arbiters: Design Ideas and Coding Styles'}, {'authors': ['Jinming Ge'], 'title': 'Round -Robin Arbiter Design'}, {'authors': ['K. C. Lee'], 'title': 'A variable round -robin arbiter for high speed buses and statistical multiplexers'}, {'authors': ['N. Sertac  Artan', 'M ing Yang H. Jonathan Chao'], 'title': 'Hierarchical Round Robin Arbiter for High -Speed, Low -Power, a nd Scalable Networks -on-Chip'}]}
# 2003.01344.pdf : {'title': 'Adaptive Federated Learning With Gradient Compression in Uplink NOMA', 'authors': ['Haijian Sun', 'Xiang Ma', 'Rose Qingyang Hu'], 'doi': None, 'references': [{'authors': ['L. T. Tan R. Q. Hu'], 'title': 'Mobility-Aware Edge Caching and Computing in Vehicle Networks: A Deep Reinforcement Learning'}, {'authors': ['I. Goodfellow', 'Y . Bengio', 'and A. Courville'], 'title': 'Deep Learning'}, {'authors': ['H. B. McManhan', 'E. Moore', 'D. Ramage', 'S. Hampson', 'and B. A. Arcas'], 'title': 'Communication-efﬁcient learning of deep networks fromdecentralized data'}, {'authors': ['Y . Lin', 'S. Han', 'H. Mao', 'Y . Wang', 'and W. J. Dally'], 'title': 'Deep gradient compression: reducing the communication bandwidth for distributedtraining'}, {'authors': ['T. Li', 'A. K. Sahu', 'M. Zaheer', 'M. Sanjabi', 'A. Talwalkar', 'and V . Smith'], 'title': 'Federated optimization in heterogeneous networks'}, {'authors': ['M. M. Amiri D. Gndz'], 'title': 'Machine learning at the wireless edge: distributed stochastic gradient descent over-the-air'}, {'authors': ['Z. Zhang', 'H. Sun R. Q. Hu'], 'title': 'Downlink and Uplink Non-Orthogonal Multiple Access in a Dense Wireless Network'}, {'authors': ['N. Zhang', 'J. Wang', 'G. Kang', 'and Y . Liu'], 'title': 'Uplink nonorthogonal multiple access in 5G systems'}, {'authors': ['S. Zhou', 'Y . Wu', 'Z. Ni', 'X. Zhou', 'H. Wen', 'and Y . Zou'], 'title': 'Dorefa-net: Training low bitwidth convolutional neural networks with low bitwidthgradients'}, {'authors': ['Mohanad M. Al-Wani', 'A. Sali', 'et al.'], 'title': 'On short term fairness and throughput of user clustering for downlink non-orthogonal multipleaccess system'}]}
# 2003.01245.pdf : {'title': 'Rectangular Pyramid Partitioning using Integrated Depth Sensors\n  (RAPPIDS): A Fast Planner for Multicopter Navigation', 'authors': ['Nathan Bucki', 'Junseok Lee', 'Mark W. Mueller'], 'doi': '10.1109/LRA.2020.3003277', 'references': [{'authors': ['H. Oleynikova', 'M. Burri', 'Z. Taylor', 'J. Nieto', 'R. Siegwart', 'and E. Gal-\nceran'], 'title': 'Continuous-time trajectory optimization for online uav replan-ning'}, {'authors': ['F. Gao', 'Y . Lin', 'and S. Shen'], 'title': 'Gradient-based online safe trajectorygeneration for quadrotor ﬂight in complex environments'}, {'authors': ['S. Liu', 'M. Watterson', 'S. Tang', 'and V . Kumar'], 'title': 'High speed navigationfor quadrotors with limited onboard sensing'}, {'authors': ['J. Chen', 'T. Liu', 'and S. Shen'], 'title': 'Online generation of collision-freetrajectories for quadrotor ﬂight in unknown cluttered environments'}, {'authors': ['J. Tordesillas', 'B. T. Lopez', 'and J. P. How'], 'title': 'Fastrap: Fast and safetrajectory planner for ﬂights in unknown environments'}, {'authors': ['P. Florence', 'J. Carter', 'and R. Tedrake'], 'title': 'Integrated perception and controlat high speed: Evaluating collision avoidance maneuvers without maps'}, {'authors': ['B. T. Lopez J. P. How'], 'title': 'Aggressive 3-d collision avoidance for high-speed navigation'}, {'authors': ['L. Matthies', 'R. Brockers', 'Y . Kuwata', 'and S. Weiss'], 'title': 'Stereo vision-basedobstacle avoidance for micro air vehicles using disparity space'}, {'authors': ['J. Zhang', 'C. Hu', 'R. G. Chadha', 'and S. Singh'], 'title': 'Maximum likelihoodpath planning for fast aerial maneuvers and collision avoidance'}, {'authors': ['A. J. Barry R. Tedrake'], 'title': 'Pushbroom stereo for high-speed navigationin cluttered environments'}, {'authors': ['P. R. Florence', 'J. Carter', 'J. Ware', 'and R. Tedrake'], 'title': 'Nanomap: Fast,uncertainty-aware proximity queries with lazy search over local 3d data'}, {'authors': ['M. Ryll', 'J. Ware', 'J. Carter', 'and N. Roy'], 'title': 'Efﬁcient trajectory planningfor high speed ﬂight in unknown environments'}, {'authors': ['M. W. Mueller', 'M. Hehn', 'and R. D’Andrea'], 'title': 'A computationally ef-ﬁcient motion primitive for quadrocopter trajectory generation'}, {'authors': ['N. Bucki M. W. Mueller'], 'title': 'Rapid collision detection for multicoptertrajectories'}, {'authors': ['S. Karaman E. Frazzoli'], 'title': 'Sampling-based algorithms for optimalmotion planning'}, {'authors': ['T. Cieslewski', 'E. Kaufmann', 'and D. Scaramuzza'], 'title': 'Rapid explorationwith multi-rotors: A frontier selection method for high speed ﬂight'}]}
# 2003.00501.pdf : {'title': 'Distributed Joint Detection and Estimation: A Sequential Approach', 'authors': ['Dominik Reinhard', 'Michael Fauß', 'Abdelhak M. Zoubir'], 'doi': None, 'references': [{'authors': ['G. V . Moustakides', 'G. H. Jajamovich', 'A. Tajer', 'and X. Wang'], 'title': 'Jointdetection and estimation: Optimum tests and applications'}, {'authors': ['D. Middleton R. Esposito'], 'title': 'Simultaneous optimum detection andestimation of signals in noise'}, {'authors': ['A. Fredriksen', 'D. Middleton', 'and V . VandeLinde'], 'title': 'Simultaneous signaldetection and estimation under multiple hypotheses'}, {'authors': ['H. Momeni', 'H. R. Abutalebi', 'and A. Tadaion'], 'title': 'Joint detection andestimation of speech spectral amplitude using noncontinuous gain func-tions'}, {'authors': ['S. Boutoille', 'S. Reboul', 'and M. Benjelloun'], 'title': 'A hybrid fusion systemapplied to off-line detection and change-points estimation'}, {'authors': ['Z. Wei', 'W. Hu', 'D. Han', 'M. Zhang', 'B. Li', 'and C. Zhao'], 'title': 'Simultaneouschannel estimation and signal detection in wireless ultraviolet commu-nications combating inter-symbol-interference'}, {'authors': ['L. Chaari', 'T. Vincent', 'F. Forbes', 'M. Dojat', 'and P. Ciuciu'], 'title': 'Fast jointdetection-estimation of evoked brain activity in event-related fMRI usinga variational approach'}, {'authors': ['A. Wald', 'Sequential Analysis . New York: Wiley', '1947.\n[9] A. Tartakovsky', 'I. Nikiforov', 'and M. Basseville', 'Sequential Analysis:\nHypothesis Testing Changepoint Detection . Boca Raton: CRC\nPress', '2014.[10] M. Ghosh', 'N. Mukhopadhyay', 'and P. K. Sen', 'Sequential Estimation', 'V . Barnett', 'R. A. Bradley', 'N. I. Fisher', 'J. S. Hunter', 'J. B. Kadane', 'D. G.\nKendall', 'D. W. Scott', 'A. F. M. Smith', 'J. L. Teugels', 'and G. S. Watson', 'Eds. New York: John Wiley & Sons', '1997.\n[11] Y . Yılmaz', 'G. V . Moustakides', 'and X. Wang'], 'title': 'Sequential joint detectionand estimation'}, {'authors': ['Y . Yılmaz', 'S. Li', 'and X. Wang'], 'title': 'Sequential joint detection and esti-mation: Optimum tests and applications'}, {'authors': ['D. Reinhard', 'M. Fauß', 'and A. M. Zoubir'], 'title': 'An approach to jointsequential detection and estimation with distributional uncertainties'}, {'authors': ['——'], 'title': 'Bayesian sequential joint detection and estimation'}, {'authors': ['D. Reinhard', 'M. Fauß', 'and A. M. Zoubir'], 'title': 'Bayesian sequential jointsignal detection and signal-to-noise ratio estimation'}, {'authors': ['——'], 'title': 'Sequential joint detection and estimation with an applicationto joint symbol decoding and noise power estimation'}, {'authors': ['M. Gölz', 'M. Muma', 'T. Halme', 'A. Zoubir', 'and V . Koivunen'], 'title': 'Spatialinference in sensor networks using multiple hypothesis testing andbayesian clustering'}, {'authors': ['S. Kar J. M. F. Moura'], 'title': 'Consensus + innovations distributedinference over networks: cooperation and sensing in networked systems'}, {'authors': ['M. R. Leonard A. M. Zoubir'], 'title': 'Robust sequential detection indistributed sensor networks'}, {'authors': ['S. Li X. Wang'], 'title': 'Fully distributed sequential hypothesis testing:Algorithms and asymptotic analyses'}, {'authors': ['A. K. Sahu S. Kar'], 'title': 'Distributed sequential detection for Gaussianshift-in-mean hypothesis testing'}, {'authors': ['L. Xiao S. Boyd'], 'title': 'Fast linear iterations for distributed averaging'}, {'authors': ['M. Fauß A. M. Zoubir'], 'title': 'A linear programming approach tosequential hypothesis testing'}, {'authors': ['I. Gurobi Optimization'], 'title': 'Gurobi optimizer reference manual'}, {'authors': ['M. Grant S. Boyd'], 'title': 'CVX: Matlab software for disciplined convexprogramming, version 2.1'}, {'authors': ['——'], 'title': 'Graph implementations for nonsmooth convex programs'}]}
# 2003.00238.pdf : {'title': 'On the Sample Complexity of Data-Driven Inference of the\n  $\\mathcal{L}_2$-gain', 'authors': ['Miel Sharf'], 'doi': '10.1109/LCSYS.2020.2996581', 'references': [{'authors': ['M. Chen', 'S. Mao', 'and Y . Liu'], 'title': 'Big data: A survey'}, {'authors': ['Z.-S. Hou Z. Wang'], 'title': 'From model-based control to data-drivencontrol: Survey, classiﬁcation and perspective'}, {'authors': ['P. Tabuada', 'W. Ma', 'J. Grizzle', 'and A. D. Ames'], 'title': 'Data-driven control forfeedback linearizable single-input systems'}, {'authors': ['S. Dean', 'H. Mania', 'N. Matni', 'B. Recht', 'and S. Tu'], 'title': 'On the sample com-plexity of the linear quadratic regulator'}, {'authors': ['B. Recht'], 'title': 'A tour of reinforcement learning: The view from continuouscontrol'}, {'authors': ['L. Ljung', 'System identiﬁcation . Wiley Online Library', '1999.\n[7] T. McKelvey', 'H. Akc ¸ay', 'and L. Ljung'], 'title': 'Subspace-based multivariablesystem identiﬁcation from frequency response data'}, {'authors': ['J. Sj ¨oberg', 'Q. Zhang', 'L. Ljung', 'A. Benveniste', 'B. Deylon', 'P.-Y . Gloren-\nnec', 'H. Hjalmarsson', 'and A. Juditsky', 'Nonlinear black-box modeling in\nsystem identiﬁcation: a uniﬁed overview . Link ¨oping University', '1995.\n[9] J. Schoukens L. Ljung'], 'title': 'Nonlinear system identiﬁcation: A user-oriented road map'}, {'authors': ['J. C. Willems', 'P. Rapisarda', 'I. Markovsky', 'and B. L. De Moor'], 'title': 'A noteon persistency of excitation'}, {'authors': ['C. De Persis P. Tesi'], 'title': 'Formulas for data-driven control: Stabilization,optimality and robustness'}, {'authors': ['J. Coulson', 'J. Lygeros', 'and F. D ¨orﬂer'], 'title': 'Data-enabled predictive control:In the shallows of the DeePC'}, {'authors': ['A. Bisofﬁ', 'C. De Persis', 'and P. Tesi'], 'title': 'Data-based guarantees of setinvariance properties'}, {'authors': ['H. Khalil', 'Nonlinear Systems . Pearson Education', 'Prentice Hall', '2002.\n[15] A. Romer', 'J. Berberich', 'J. K ¨ohler', 'and F. Allg ¨ower'], 'title': 'One-shot veriﬁ-cation of dissipativity properties from input-output data'}, {'authors': ['A. Romer', 'J. M. Montenbruck', 'and F. Allg ¨ower'], 'title': 'Sampling strategiesfor data-driven inference of passivity properties'}, {'authors': ['A. Romer', 'S. Trimpe', 'and F. Allgwer'], 'title': 'Data-driven inference of passivityproperties via gaussian process optimization'}, {'authors': ['M. Tanemura S.-I. Azuma'], 'title': 'Efﬁcient data-driven estimation ofpassivity properties'}, {'authors': ['J. M. Montenbruck F. Allg ¨ower'], 'title': 'Some problems arising in con-troller design from big data via input-output methods'}, {'authors': ['A. Romer', 'J. M. Montenbruck', 'and F. Allg ¨ower'], 'title': 'Determining dissipa-tion inequalities from input-output samples'}, {'authors': ['S. Shalev-Shwartz S. Ben-David', 'Understanding machine learning:\nFrom theory to algorithms . Cambridge university press', '2014.\n[22] R. M. Dudley'], 'title': 'The sizes of compact subsets of hilbert space andcontinuity of gaussian processes'}, {'authors': ['A. Wilansky', 'Topology for analysis . Courier Corporation', '2008.\n[24] J. T. Schwartz H. Karcher', 'Nonlinear functional analysis . CRC\nPress', '1969.\n[25] A. V . Akopyan A. S. Tarasov'], 'title': 'A constructive proof of kirszbraunstheorem'}, {'authors': ['D. Azagra', 'E. L. Gruyer', 'and C. Mudarra'], 'title': 'Kirszbraun’s theorem via anexplicit formula'}]}
# 2003.00971.pdf : {'title': 'Graphing Website Relationships for Risk Prediction: Identifying Derived\n  Threats to Users Based on Known Indicators', 'authors': ['Philip H. Kulp', 'Nikki E. Robinson'], 'doi': '10.1007/978-3-030-63089-8', 'references': [{'authors': ['D. Chiba', 'K. Tobe', 'T. Mori', 'and S. Goto. Detecting Malicious Websites by Learning IP Address Features. \n2012 IEEE/IPSJ 12th International Symposium on Applications the Internet', '29 –39. \n[2] T. Fawcett'], 'title': 'An introduction to ROC analysis'}, {'authors': ['F. Gillani', 'E. Al -Shaer', 'and B. AsSadhan. Economic Metric to Improve Spam Detectors. Journal of \nNetwork Computer Application', '65(C)', '131 –143.  \n[4] Z. Gyöngyi', 'H. Garcia -Molina', 'and J. P edersen'], 'title': 'Combating Web Spam with Trustrank'}, {'authors': ['S. Wen', 'Z. Zhao', 'and H. Yan'], 'title': 'Detecting Malicious Websites in Depth through Ana lyzing Topics and Web -pages'}, {'authors': ['B. S. Rawal', 'S. Liang', 'A. Loukili', 'and Q. Duan'], 'title': 'Anticipatory Cyber Security Research: A n Ultimate Technique for the First -Move Advantage'}, {'authors': ['H. de Bruijn M. Janssen'], 'title': 'Building cybersecurity awareness: The need for evidence -based framing strategies'}, {'authors': ['J. Schwarz M. Morris'], 'title': 'Augmenting web pages and search results to support credibility assessment'}, {'authors': ['P. Kulp . (Doctoral dissertation). Active Cyber Defense: A Case  Study on Responses to Cyberattacks . \nRetrieved from ProQuest Dissertations Theses database. (UMI No. 13886134 ). \n[10] X. Chen. http -sniffer. https://github.com/caesar0301/http -sniffer.  \n[11] R. Edwards. Neomodel. https://neomodel.readthedocs.io/en/latest.  \n[12] M. H. Zweig G. Campbell'], 'title': 'Receiver -operating characteristic (ROC) plots: a fundamental evaluation tool in clinical medicine'}]}
# 2003.01649.pdf : {'title': 'Robotic Grasping through Combined Image-Based Grasp Proposal and 3D\n  Reconstruction', 'authors': ['Daniel Yang', 'Tarik Tosun', 'Ben Eisner', 'Volkan Isler', 'Daniel Lee'], 'doi': None, 'references': [{'authors': ['J. Mahler', 'J. Liang', 'S. Niyaz', 'M. Laskey', 'R. Doan', 'X. Liu', 'J. A. Ojea', 'and K. Goldberg'], 'title': 'Dex-net 2.0: Deep learning to plan robust graspswith synthetic point clouds and analytic grasp metrics'}, {'authors': ['A. Zeng', 'S. Song', 'K.-T. Yu', 'E. Donlon', 'F. R. Hogan', 'M. Bauza', 'D. Ma', 'O. Taylor', 'M. Liu', 'E. Romo', 'et al.'], 'title': 'Robotic pick-and-placeof novel objects in clutter with multi-affordance grasping and cross-domain image matching'}, {'authors': ['A. Mousavian', 'C. Eppner', 'and D. Fox'], 'title': '6-dof graspnet: Variationalgrasp generation for object manipulation'}, {'authors': ['P. R. Florence', 'L. Manuelli', 'and R. Tedrake'], 'title': 'Dense object nets: Learn-ing dense visual object descriptors by and for robotic manipulation'}, {'authors': ['K. He', 'X. Zhang', 'S. Ren', 'and J. Sun'], 'title': 'Deep residual learning for imagerecognition'}, {'authors': ['G. Huang', 'Z. Liu', 'L. van der Maaten', 'and K. Q. Weinberger'], 'title': 'Densely connected convolutional networks'}, {'authors': ['B. Calli', 'A. Singh', 'J. Bruce', 'A. Walsman', 'K. Konolige', 'S. Srinivasa', 'P. Abbeel', 'and A. M. Dollar'], 'title': 'Yale-cmu-berkeley dataset forrobotic manipulation research'}, {'authors': ['A. T. Miller P. K. Allen'], 'title': 'Graspit! a versatile simulator for roboticgrasping'}, {'authors': ['M. Ciocarlie', 'K. Hsiao', 'E. G. Jones', 'S. Chitta', 'R. B. Rusu', 'and\nI. A. S ¸ucan'], 'title': 'Towards reliable grasping and manipulation in householdenvironments'}, {'authors': ['A. Zeng', 'S. Song', 'J. Lee', 'A. Rodriguez', 'and T. Funkhouser'], 'title': 'Tossing-bot: Learning to throw arbitrary objects with residual physics'}, {'authors': ['J. Mahler', 'M. Matl', 'X. Liu', 'A. Li', 'D. Gealy', 'and K. Goldberg'], 'title': 'Dex-net 3.0: Computing robust vacuum suction grasp targets in pointclouds using a new analytic model and deep learning'}, {'authors': ['A. ten Pas', 'M. Gualtieri', 'K. Saenko', 'and R. Platt'], 'title': 'Grasp posedetection in point clouds'}, {'authors': ['D. Kingma M. Welling'], 'title': 'Auto-encoding variational bayes'}, {'authors': ['C. B. Choy', 'D. Xu', 'J. Gwak', 'K. Chen', 'and S. Savarese'], 'title': '3d-r2n2: Auniﬁed approach for single and multi-view 3d object reconstruction'}, {'authors': ['N. Wang', 'Y . Zhang', 'Z. Li', 'Y . Fu', 'W. Liu', 'and Y .-G. Jiang'], 'title': 'Pixel2mesh:Generating 3d mesh models from single rgb images'}, {'authors': ['J. J. Park', 'P. Florence', 'J. Straub', 'R. Newcombe', 'and S. Lovegrove'], 'title': 'Deepsdf: Learning continuous signed distance functions for shaperepresentation'}, {'authors': ['H. Fan', 'H. Su', 'and L. J. Guibas'], 'title': 'A point set generation network for3d object reconstruction from a single image'}, {'authors': ['J. Varley', 'C. DeChant', 'A. Richardson', 'J. Ruales', 'and P. Allen'], 'title': 'Shapecompletion enabled robotic grasping'}, {'authors': ['D. Watkins-Valls', 'J. Varley', 'and P. Allen'], 'title': 'Multi-modal geometriclearning for grasping and manipulation'}, {'authors': ['E. Mitchell', 'S. Engin', 'V . Isler', 'and D. D. Lee'], 'title': 'Higher-order func-tion networks for learning composable 3d object representations'}, {'authors': ['L. Manuelli', 'W. Gao', 'P. Florence', 'and R. Tedrake'], 'title': 'kpam: Keypointaffordances for category-level robotic manipulation'}, {'authors': ['W. Gao R. Tedrake'], 'title': 'kpam-sc: Generalizable manipulation plan-ning using keypoint affordance and shape completion'}, {'authors': ['T. Tosun\x03', 'E. Mitchell\x03', 'B. Eisner', 'J. Huh', 'B. Lee', 'D. Lee', 'V . Isler', 'H. S. Seung', 'and D. Lee'], 'title': 'Pixels to plans: Learning non-prehensilemanipulation by imitating a planner'}, {'authors ...
# 2003.01340.pdf : {'title': 'Design of Convergence-Optimized Non-binary LDPC Codes over Binary\n  Erasure Channel', 'authors': ['Yang Yu', 'Wen Chen', 'Lili Wei'], 'doi': None, 'references': [{'authors': ['V . Savin'], 'title': 'Non binary ldpc codes over the binaryerasure channel: density evolution analysis'}, {'authors': ['G. Li', 'I. Fair', 'and W. Krzymien'], 'title': 'Density evolution for no nbinary ldpccodes under gaussian approximation'}, {'authors': ['A. E. Ashikhmin', 'G. Kramer', 'and S. ten Brink'], 'title': 'Extrinsic i nformationtransfer functions: model and erasure channel properties,'}, {'authors': ['V . Savin'], 'title': 'Binary linear-time erasure decoding for non- binary ldpc codes'}, {'authors': ['R. Lidl', 'Introduction to ﬁnite ﬁelds their applications. Cambridge', '2002.\n[6] X. Ma B. Bai'], 'title': 'A uniﬁed decoding algorithm for linear c odes basedon partitioned parity-check matrices'}, {'authors': ['M. Luby', 'M. Mitzenmacher', 'M. A. Shokrollahi', 'D. A. Spielm an', 'and\nV . Stemann'], 'title': 'Practical loss-resilient codes.'}, {'authors': ['B. Smith', 'M. Ardakani', 'W. Yu', 'and F. Kschischang'], 'title': 'Design of irreg-ular ldpc codes with optimized performance-complexity tra deoff'}]}
# 2003.01554.pdf : {'title': 'Underactuated Waypoint Trajectory Optimization for Light Painting\n  Photography', 'authors': ['Christian Eilers', 'Jonas Eschmann', 'Robin Menzenbach', 'Boris Belousov', 'Fabio Muratore', 'Jan Peters'], 'doi': None, 'references': [{'authors': ['M. W. Spong'], 'title': 'Underactuated mechanical systems'}, {'authors': ['H. M. Choset', 'S. Hutchinson', 'K. M. Lynch', 'G. Kantor', 'W. Burgard', 'L. E. Kavraki', 'and S. Thrun', 'Principles of robot motion: theory', 'algorithms', 'and implementation . MIT press', '2005.\n[3] R. Tedrake. Underactuated robotics: Algorithms for walking', 'running', 'swimming', 'ﬂying', 'and manipulation (course notes for MIT 6.832).\n[Online]. Available: http://underactuated.mit.edu/\n[4] M. W. Spong'], 'title': 'Partial feedback linearization of underactuated mechan-ical systems'}, {'authors': ['I. Fantoni R. Lozano', 'Non-linear control for underactuated\nmechanical systems . Springer Science & Business Media', '2001.\n[6] J. Lin', 'N. Somani', 'B. Hu', 'M. Rickert', 'and A. Knoll'], 'title': 'An efﬁcientand time-optimal trajectory generation approach for waypoints underkinematic constraints and error bounds'}, {'authors': ['J. Schultz T. Murphey'], 'title': 'Trajectory generation for underactuatedcontrol of a suspended mass'}, {'authors': ['K. Furuta', 'M. Yamakita', 'and S. Kobayashi'], 'title': 'Swing-up control ofinverted pendulum using pseudo-state feedback'}, {'authors': ['B. S. Cazzolato Z. Prime'], 'title': 'On the dynamics of the furutapendulum'}, {'authors': ['J. T. Betts'], 'title': 'Survey of numerical methods for trajectory optimization'}, {'authors': ['C. R. Hargraves S. W. Paris'], 'title': 'Direct trajectory optimizationusing nonlinear programming and collocation'}, {'authors': ['J. A. E. Andersson', 'J. Gillis', 'G. Horn', 'J. B. Rawlings', 'and M. Diehl'], 'title': 'CasADi – A software framework for nonlinear optimization andoptimal control'}, {'authors': ['F. L. Lewis', 'D. Vrabie', 'and V . L. Syrmos', 'Optimal control . John\nWiley & Sons', '2012.\n[14] A. W. Divelbiss J. T. Wen'], 'title': 'Trajectory tracking control of a car-trailer system'}, {'authors': ['A. Marco', 'P. Hennig', 'J. Bohg', 'S. Schaal', 'and S. Trimpe'], 'title': 'Automaticlqr tuning based on gaussian process global optimization'}, {'authors': ['Quanser Inc.'], 'title': 'Qube-servo 2 workbook - student version'}]}
# 2003.01309.pdf : {'title': 'Controllable Time-Delay Transformer for Real-Time Punctuation Prediction\n  and Disfluency Detection', 'authors': ['Qian Chen', 'Mengzhe Chen', 'Bo Li', 'Wen Wang'], 'doi': None, 'references': [{'authors': ['Mingbo Ma', 'Liang Huang', 'Hao Xiong', 'Renjie Zheng', 'Kaibo\nLiu', 'Baigong Zheng', 'Chuanqiang Zhang', 'Zhongjun He', 'Hairong Liu', 'Xing Li', 'Hua Wu', 'and Haifeng Wang'], 'title': 'STACL:simultaneous translation with implicit anticipation and control-lable latency using preﬁx-to-preﬁx framework'}, {'authors': ['Jiangyan Yi Jianhua Tao'], 'title': 'Self-attention based model forpunctuation prediction using word and speech embeddings'}, {'authors': ['Qianqian Dong', 'Feng Wang', 'Zhen Yang', 'Wei Chen', 'Shuang\nXu', 'and Bo Xu'], 'title': 'Adapting translation models for transcriptdisﬂuency detection'}, {'authors': ['Xuancong Wang', 'Khe Chai Sim', 'and Hwee Tou Ng'], 'title': 'Com-bining punctuation and disﬂuency prediction: An empiricalstudy'}, {'authors': ['Don Baron', 'Elizabeth Shriberg', 'and Andreas Stolcke'], 'title': 'Au-tomatic punctuation and disﬂuency detection in multi-partymeetings using prosodic and lexical cues'}, {'authors': ['Zhixing Tan', 'Mingxuan Wang', 'Jun Xie', 'Yidong Chen', 'and Xi-\naodong Shi'], 'title': 'Deep semantic role labeling with self-attention'}, {'authors': ['Eunah Cho', 'Jan Niehues', 'and Alex Waibel'], 'title': 'Segmentation andpunctuation prediction in speech language translation using amonolingual translation system'}, {'authors': ['Eunah Cho', 'Jan Niehues', 'Kevin Kilgour', 'and Alex Waibel'], 'title': 'Punctuation insertion for real-time spoken language transla-tion'}, {'authors': ['Binh Nguyen', 'Vu Bao Hung Nguyen', 'Hien Nguyen', 'Pham Ngoc Phuong', 'The-Loc Nguyen', 'Quoc Truong Do', 'and\nLuong Chi Mai'], 'title': 'Fast and accurate capitalization and punctu-ation for automatic speech recognition using transformer andchunk merging'}, {'authors': ['Ottokar Tilk Tanel Alum ¨ae'], 'title': 'Bidirectional recurrent neu-ral network with attention mechanism for punctuation restora-tion'}, {'authors': ['Yang Liu', 'Elizabeth Shriberg', 'Andreas Stolcke', 'Dustin Hillard', 'Mari Ostendorf', 'and Mary P. Harper'], 'title': 'Enriching speech recog-nition with automatic detection of sentence boundaries and dis-ﬂuencies'}, {'authors': ['Doug Beeferman', 'Adam L. Berger', 'and John D. Lafferty'], 'title': 'Cyberpunc: a lightweight punctuation annotation system forspeech'}, {'authors': ['Heidi Christensen', 'Yoshihiko Gotoh', 'and Steve Renals'], 'title': 'Punc-tuation annotation using statistical prosody models'}, {'authors': ['Nicola Uefﬁng', 'Maximilian Bisani', 'and Paul V ozila'], 'title': 'Im-proved models for automatic punctuation prediction for spokenand written text'}, {'authors': ['Piotr Zelasko', 'Piotr Szymanski', 'Jan Mizgajski', 'Adrian Szym-\nczak', 'Yishay Carmiel', 'and Najim Dehak'], 'title': 'Punctuation predic-tion model for conversational speech'}, {'authors': ['Wei Lu Hwee Tou Ng'], 'title': 'Better punctuation predictionwith dynamic conditional random ﬁelds'}, {'authors': ['Xiaoyin Che', 'Cheng Wang', 'Haojin Yang', 'and Christoph\nMeinel'], 'title': 'Punctuation prediction for unsegmented transcriptbased on word vector'}, {'authors': ['Ottokar Tilk Tanel Alum ¨ae'], 'title': 'LSTM for punctuationrestoration in speech transcripts'}, {'authors': ['Jiangyan Yi', 'Jianhua Tao', 'Zhengqi Wen', 'and Ya Li'], 'title': 'Distillingknowledge from an ensemble of models for punctuation pre-diction'}, {'authors': ['Stephan Peitz', 'Markus Freitag', 'Arne Mauser', 'and Hermann\nNey'], 'title': 'Modeling punctuation prediction as machine transla-tion'}, {'authors': ['Ondrej Klejch', 'Peter Bell', 'and Steve Renals'], 'title': 'Punctuated tran-scription of multi-genre broadcasts using acoustic and lexicalapproaches'}, {'authors': ['Mari Ostendorf Sangyun Hahn'], 'title': 'A sequential repetitionmodel for improved disﬂuency detection'}, {'author ...
# ...
# 2003.00188.pdf : {'title': 'Robust 6D Object Pose Estimation by Learning RGB-D Features', 'authors': ['Meng Tian', 'Liang Pan', 'Marcelo H Ang', 'Gim Hee Lee'], 'doi': None, 'references': [{'authors': ['N. Correll', 'K. E. Bekris', 'D. Berenson', 'O. Brock', 'A. Causo', 'K. Hauser', 'K. Okada', 'A. Rodriguez', 'J. M. Romano', 'and P. R. Wurman'], 'title': 'Analysisand observations from the ﬁrst amazon picking challenge'}, {'authors': ['J. Tremblay', 'T. To', 'B. Sundaralingam', 'Y . Xiang', 'D. Fox', 'and S. Birch-\nﬁeld'], 'title': 'Deep object pose estimation for semantic robotic grasping ofhousehold objects'}, {'authors': ['W. Kehl', 'F. Manhardt', 'F. Tombari', 'S. Ilic', 'and N. Navab'], 'title': 'Ssd-6d:Making rgb-based 3d detection and 6d pose estimation great again'}, {'authors': ['B. Tekin', 'S. N. Sinha', 'and P. Fua'], 'title': 'Real-time seamless single shot6d object pose prediction'}, {'authors': ['Y . Xiang', 'T. Schmidt', 'V . Narayanan', 'and D. Fox'], 'title': 'Posecnn: Aconvolutional neural network for 6d object pose estimation in clutteredscenes'}, {'authors': ['M. Sundermeyer', 'Z.-C. Marton', 'M. Durner', 'M. Brucker', 'and\nR. Triebel'], 'title': 'Implicit 3d orientation learning for 6d object detectionfrom rgb images'}, {'authors': ['S. Peng', 'Y . Liu', 'Q. Huang', 'X. Zhou', 'and H. Bao'], 'title': 'Pvnet: Pixel-wisevoting network for 6dof pose estimation'}, {'authors': ['S. Zakharov', 'I. Shugurov', 'and S. Ilic'], 'title': 'Dpod: Dense 6d pose objectdetector in rgb images'}, {'authors': ['M. Oberweger', 'M. Rad', 'and V . Lepetit'], 'title': 'Making deep heatmaps robustto partial occlusions for 3d object pose estimation'}, {'authors': ['Y . Hu', 'J. Hugonot', 'P. Fua', 'and M. Salzmann'], 'title': 'Segmentation-driven6d object pose estimation'}, {'authors': ['T. Hodan', 'F. Michel', 'E. Brachmann', 'W. Kehl', 'A. GlentBuch', 'D. Kraft', 'B. Drost', 'J. Vidal', 'S. Ihrke', 'X. Zabulis', 'et al.'], 'title': 'Bop: benchmark for 6dobject pose estimation'}, {'authors': ['C. Li', 'J. Bai', 'and G. D. Hager'], 'title': 'A uniﬁed framework for multi-viewmulti-class object pose estimation'}, {'authors': ['C. Wang', 'D. Xu', 'Y . Zhu', 'R. Mart ´ın-Mart ´ın', 'C. Lu', 'L. Fei-Fei', 'and\nS. Savarese'], 'title': 'Densefusion: 6d object pose estimation by iterative densefusion'}, {'authors': ['C. R. Qi', 'H. Su', 'K. Mo', 'and L. J. Guibas'], 'title': 'Pointnet: Deep learningon point sets for 3d classiﬁcation and segmentation'}, {'authors': ['D. Novotny', 'S. Albanie', 'D. Larlus', 'and A. Vedaldi'], 'title': 'Self-supervisedlearning of geometrically stable features through probabilistic intro-spection'}, {'authors': ['J. Li G. H. Lee'], 'title': 'Usip: Unsupervised stable interest point detectionfrom 3d point clouds'}, {'authors': ['S. Hinterstoisser', 'V . Lepetit', 'S. Ilic', 'S. Holzer', 'G. Bradski', 'K. Konolige', 'and N. Navab'], 'title': 'Model based training, detection and pose estimation oftexture-less 3d objects in heavily cluttered scenes'}, {'authors': ['D. G. Lowe'], 'title': 'Distinctive image features from scale-invariant key-points'}, {'authors': ['D. G. Lowe'], 'title': 'Object recognition from local scale-invariantfeatures.'}, {'authors': ['E. Brachmann', 'A. Krull', 'F. Michel', 'S. Gumhold', 'J. Shotton', 'and\nC. Rother'], 'title': 'Learning 6d object pose estimation using 3d objectcoordinates'}, {'authors': ['E. Brachmann', 'F. Michel', 'A. Krull', 'M. Ying Yang', 'S. Gumhold', 'et al.'], 'title': 'Uncertainty-driven 6d pose estimation of objects and scenesfrom a single rgb image'}, {'authors': ['W. Liu', 'D. Anguelov', 'D. Erhan', 'C. Szegedy', 'S. Reed', 'C.-Y . Fu', 'and A. C. Berg'], 'title': 'Ssd: Single shot multibox detector'}, {'authors': ['M. Rad V . Lepetit'], 'title': 'Bb8: a scalable, accurate, robust to partialocclusion method for predicting the 3d poses of challenging objectswithout using depth'}, {'authors': ['A. Krull', 'E. Brachmann', 'F. Michel', 'M. Ying Yang', 'S. Gumho ...
# 2003.00001.pdf : {'title': 'The mathematics of Bitcoin', 'authors': ['Cyril Grunspan', 'Ricardo Pérez-Marco'], 'doi': None, 'references': [{'authors': ['S. Nakamoto'], 'title': 'Bitcoin: A peer-to-peer electronic cash system'}, {'authors': ['R. Pérez-Marco'], 'title': 'Bitcoin and decentralized trust protocols'}, {'authors': ['C. Grunspan R. Pérez-Marco'], 'title': 'Double spend races'}, {'authors': ['M. Rosenfeld'], 'title': 'Analysis of hashrate-based double spending'}, {'authors': ['C. Grunspan R. Pérez-Marco'], 'title': 'Satoshi risk tables'}, {'authors': ['E. Giogladis D. Zeilberger'], 'title': 'A combinatorial-probabilistic analy-sis of bitcoin attacks'}, {'authors': ['C. Grunspan R. Pérez-Marco'], 'title': 'On the proﬁtability of selﬁsh min-ing'}, {'authors': ['I. Eyal E. G. Sirer'], 'title': 'Majority is not enough: Bitcoin mining isvulnerable'}, {'authors': ['K. Nayak', 'S. Kumar', 'A. K. Miller', 'and E. Shi'], 'title': 'Stubborn mining:Generalizing selﬁsh mining and combining with an eclipse attack'}, {'authors': ['C. Grunspan R. Pérez-Marco'], 'title': 'On the proﬁtability of stubbornmining'}, {'authors': ['C. Grunspan R. Pérez-Marco'], 'title': 'On the proﬁtability of trailing min-ing'}, {'authors': ['C. Grunspan R. Pérez-Marco'], 'title': 'Bitcoin selﬁsh mining and Dyckwords'}, {'authors': ['C. Grunspan R. Pérez-Marco'], 'title': 'Selﬁsh mining in Ethereum'}, {'authors': ['C. Grunspan R. Pérez-Marco'], 'title': 'On proﬁtability of nakamoto dou-ble spend'}]}
# 2003.01846.pdf : {'title': 'New Examples of Minimal Non-Strongly-Perfect Graphs', 'authors': ['Maria Chudnovsky', 'Cemil Dibek', 'Paul Seymour'], 'doi': None, 'references': [{'authors': ['V. Anastasoaei', 'E. Olaru.'], 'title': 'New results on minimal strong ly imperfect graphs'}, {'authors': ['C. Berge', 'P. Duchet.'], 'title': 'Strongly perfect graphs'}, {'authors': ['M. Chudnovsky', 'C. Dibek'], 'title': 'Strongly Perfect Claw-free Gr aphs - A Short Proof'}, {'authors': ['C.T. Ho´ ang', 'F. Maﬀray', 'M. Preissmann.'], 'title': 'New properties o f perfectly orderable graphs andstrongly perfect graphs'}, {'authors': ['S. Olariu.'], 'title': 'A decomposition for strongly perfect graphs'}, {'authors': ['M. Preissmann.'], 'title': 'A class of strongly perfect graphs'}, {'authors': ['G. Ravindra.'], 'title': 'Strongly perfect line graphs and total gra phs'}, {'authors': ['G. Ravindra.'], 'title': 'Research problems'}, {'authors': ['G. Ravindra.'], 'title': 'Some classes of strongly perfect graphs'}, {'authors': ['H.Y. Wang.'], 'title': 'Which claw-free graphs are strongly perfec t?'}]}
# 2003.00147.pdf : {'title': 'Zero-Forcing Max-Power Beamforming for Hybrid mmWave Full-Duplex MIMO\n  Systems', 'authors': ['Elyes Balti', 'Neji Mensi'], 'doi': None, 'references': [{'authors': ['R. W. Heath', 'N. Gonz ´alez-Prelcic', 'S. Rangan', 'W. Roh', 'and A. M.\nSayeed'], 'title': 'An overview of signal processing techniques for millimeterwave MIMO systems'}, {'authors': ['E. Onggosanusi', 'M. S. Rahman', 'L. Guo', 'Y . Kwak', 'H. Noh', 'Y . Kim', 'S. Faxer', 'M. Harrison', 'M. Frenne', 'S. Grant', 'R. Chen', 'R. Tamrakar', 'and\na. Q. Gao'], 'title': 'Modular and high-resolution channel state information andbeam management for 5G new radio'}, {'authors': ['E. Balti M. Guizani'], 'title': 'Impact of non-linear high-power ampliﬁers oncooperative relaying systems'}, {'authors': ['E. Balti', 'M. Guizani', 'B. Hamdaoui', 'and B. Khalﬁ'], 'title': 'Aggregate hardwareimpairments over mixed RF/FSO relaying systems with outdated CSI'}, {'authors': ['E. Balti M. Guizani'], 'title': 'Mixed RF/FSO cooperative relaying systemswith co-channel interference'}, {'authors': ['E. Balti', 'M. Guizani', 'B. Hamdaoui', 'and Y . Maalej'], 'title': 'Partial relayselection for hybrid RF/FSO systems with hardware impairments'}, {'authors': ['E. Balti', 'M. Guizani', 'and B. Hamdaoui'], 'title': 'Hybrid Rayleigh and Double-Weibull over impaired RF/FSO system with outdated CSI'}, {'authors': ['E. Balti', 'M. Guizani', 'B. Hamdaoui', 'and B. Khalﬁ'], 'title': 'Mixed RF/FSOrelaying systems with hardware impairments'}, {'authors': ['E. Balti B. K. Johnson'], 'title': 'Tractable approach to mmWaves cellularanalysis with FSO backhauling under feedback delay and hardwarelimitations'}, {'authors': ['C. R. Anderson', 'S. Krishnamoorthy', 'C. G. Ranson', 'T. J. Lemon', 'W. G.\nNewhall', 'T. Kummetz', 'and J. H. Reed'], 'title': 'Antenna isolation, widebandmultipath propagation measurements, and interference mitigation for on-frequency repeaters'}, {'authors': ['M. Jain', 'J. I. Choi', 'T. Kim', 'D. Bharadia', 'S. Seth', 'K. Srinivasan', 'P. Levis', 'S. Katti', 'and P. Sinha'], 'title': 'Practical, real-time, full duplex wireless'}, {'authors': ['M. Duarte', 'C. Dick', 'and A. Sabharwal'], 'title': 'Experiment-driven characteri-zation of full-duplex wireless systems'}, {'authors': ['E. Everett', 'C. Shepard', 'L. Zhong', 'and A. Sabharwal'], 'title': 'Softnull: Many-antenna full-duplex wireless via digital beamforming'}, {'authors': ['M. R. Ren ´e Escalante', 'Alternating Projection Methods', 'ser. Fundamen-\ntals of Algorithms. SIAM', '2011.\n[15] X. Liu', 'Z. Xiao', 'L. Bai', 'J. Choi', 'P. Xia', 'and X.-G. Xia'], 'title': 'Beamformingbased full-duplex for millimeter-wave communication'}]}
# 2003.00303.pdf : {'title': 'Grounded and Controllable Image Completion by Incorporating Lexical\n  Semantics', 'authors': ['Shengyu Zhang', 'Tan Jiang', 'Qinghao Huang', 'Ziqi Tan', 'Zhou Zhao', 'Siliang Tang', 'Jin Yu', 'Hongxia Yang', 'Yi Yang', 'Fei Wu'], 'doi': None, 'references': [{'authors': ['M. Bertalmio', 'G. Sapiro', 'V . Caselles', 'and C. Ballester'], 'title': 'Image inpaint-ing'}, {'authors': ['A. Levin', 'A. Zomet', 'and Y . Weiss'], 'title': 'Learning how to inpaint from globalimage statistics'}, {'authors': ['C. Barnes', 'E. Shechtman', 'A. Finkelstein', 'and D. B. Goldman'], 'title': 'Patch-Match: A randomized correspondence algorithm for structural imageediting'}, {'authors': [], 'title': 'Image completion using low tensor tree rank and total variationminimization.'}, {'authors': ['J. Liu', 'S. Yang', 'Y . Fang', 'and Z. Guo'], 'title': 'Structure-guided image inpaintingusing homography transformation.'}, {'authors': ['Y . Zeng', 'J. Fu', 'H. Chao', 'and B. Guo'], 'title': 'Learning Pyramid-ContextEncoder Network for High-Quality Image Inpainting'}, {'authors': ['J. Hays A. A. Efros'], 'title': 'Scene completion using millions of pho-tographs'}, {'authors': ['Z. Zhu', 'H.-Z. Huang', 'Z.-P. Tan', 'K. Xu', 'and S.-M. Hu'], 'title': 'Faithfulcompletion of images of scenic landmarks using internet images'}, {'authors': ['Y . Zhao', 'B. Price', 'S. Cohen', 'and D. Gurari'], 'title': 'Unconstrained foregroundobject search'}, {'authors': ['D. Pathak', 'P. Krahenbuhl', 'J. Donahue', 'T. Darrell', 'and A. A. Efros'], 'title': 'Context encoders: Feature learning by inpainting'}, {'authors': ['S. Iizuka', 'E. Simo-Serra', 'and H. Ishikawa'], 'title': 'Globally and locallyconsistent image completion'}, {'authors': ['C. Yang', 'X. Lu', 'Z. Lin', 'E. Shechtman', 'O. Wang', 'and H. Li'], 'title': 'High-resolution image inpainting using multi-scale neural patch synthesis'}, {'authors': ['R. A. Yeh', 'C. Chen', 'T. Yian Lim', 'A. G. Schwing', 'M. Hasegawa-Johnson', 'and M. N. Do'], 'title': 'Semantic image inpainting with deep generativemodels'}, {'authors': ['M.-c. Sagong', 'Y .-g. Shin', 'S.-w. Kim', 'S. Park', 'and S.-j. Ko'], 'title': 'Pepsi: Fastimage inpainting with parallel decoding network'}, {'authors': ['Z. Yan', 'X. Li', 'M. Li', 'W. Zuo', 'and S. Shan'], 'title': 'Shift-net: Image inpaintingvia deep feature rearrangement'}, {'authors': ['Y . Song', 'C. Yang', 'Z. Lin', 'X. Liu', 'Q. Huang', 'H. Li', 'and C.-C. Jay Kuo'], 'title': 'Contextual-based image inpainting: Infer, match, and translate'}, {'authors': ['G. Liu', 'F. A. Reda', 'K. J. Shih', 'T.-C. Wang', 'A. Tao', 'and B. Catanzaro'], 'title': 'Image inpainting for irregular holes using partial convolutions'}, {'authors': ['J. Yu', 'Z. Lin', 'J. Yang', 'X. Shen', 'X. Lu', 'and T. S. Huang'], 'title': 'Generativeimage inpainting with contextual attention'}, {'authors': ['W. Xiong', 'J. Yu', 'Z. Lin', 'J. Yang', 'X. Lu', 'C. Barnes', 'and J. Luo'], 'title': 'Foreground-aware image inpainting'}, {'authors': ['C. Zheng', 'T.-J. Cham', 'and J. Cai'], 'title': 'Pluralistic Image Completion'}, {'authors': ['A. Criminisi', 'P. Perez', 'and K. Toyama'], 'title': 'Region ﬁlling and objectremoval by exemplar-based image inpainting'}, {'authors': ['T. N. Kipf M. Welling'], 'title': 'Semi-supervised classiﬁcation with graphconvolutional networks'}, {'authors': ['R. Cadene', 'C. Dancette', 'H. Ben-younes', 'M. Cord', 'and D. Parikh'], 'title': 'RUBi:Reducing Unimodal Biases in Visual Question Answering'}, {'authors': ['D. He', 'Y . Xia', 'T. Qin', 'L. Wang', 'N. Yu', 'T.-Y . Liu', 'and W.-Y . Ma'], 'title': 'Duallearning for machine translation'}, {'authors': ['S. Kazemzadeh', 'V . Ordonez', 'M. Matten', 'and T. Berg'], 'title': 'Referitgame:Referring to objects in photographs of natural scenes'}, {'authors': ['Y . Li', 'S. Liu', 'J. Yang', 'and M.-H. Yang'], 'title': 'Generative face completion'}, {'authors': ['J. Yu', 'Z. Lin', 'J. Yang', 'X. Shen', 'X. Lu', 'and T. S. H ...
# 2003.00621.pdf : {'title': 'Graph Signal Processing of Indefinite and Complex Graphs using Directed\n  Variation', 'authors': ['Kevin Schultz', 'Marisel Villafane-Delgado'], 'doi': None, 'references': [{'authors': ['D. Shuman', 'S. Narang', 'P. Frossard', 'A. Ortega', 'and P. Vande rgheynst'], 'title': 'The emerging ﬁeld of signal processing on graphs: Extendin g high-dimensional data analysis to networks and other irregular d omains'}, {'authors': ['A. Sandryhaila J. M. Moura'], 'title': 'Discrete signal process ing on graphs'}, {'authors': ['A. Raj', 'C. Cai', 'X. Xie', 'E. Palacios', 'J. Owen', 'P. Mukherjee', 'and\nS. Nagarajan'], 'title': 'Spectral graph theory of brain oscillations'}, {'authors': ['R. Anirudh', 'J. J. Thiagarajan', 'R. Sridhar', 'and T. Bremer'], 'title': 'Margin:Uncovering deep neural networks using graph signal analysi s'}, {'authors': ['M. Puschel J. M. Moura'], 'title': 'Algebraic signal processing theory:Foundation and 1-d time'}, {'authors': ['F. R. Chung F. C. Graham', 'Spectral graph theory . American\nMathematical Soc.', '1997', 'no. 92.\n[7] R. Shaﬁpour', 'A. Khodabakhsh', 'G. Mateos', 'and E. Nikolova'], 'title': 'A directedgraph fourier transform with spread frequency components,'}, {'authors': ['J. C. Eccles'], 'title': 'From electrical to chemical transmission in the centralnervous system: the closing address of the sir henry dale cen tennialsymposium cambridge, 19 september 1975'}, {'authors': ['A. Sandryhaila J. M. Moura'], 'title': 'Discrete signal process ing on graphs:Frequency analysis'}, {'authors': ['Z. Lin', 'L. Wang', 'Z. Han', 'and M. Fu'], 'title': 'Distributed formatio n controlof multi-agent systems using complex laplacian'}, {'authors': ['J. Sanchez', 'R. Caire', 'and N. Hadjsaid'], 'title': 'ICT and electric power systemsinterdependencies modeling'}, {'authors': ['E. P. Frady F. T. Sommer'], 'title': 'Robust computation with rh ythmic spikepatterns'}, {'authors': ['A. Edelman', 'T. A. Arias', 'and S. T. Smith'], 'title': 'The geometry of algorithmswith orthogonality constraints'}, {'authors': ['Z. Wen W. Yin'], 'title': 'A feasible method for optimization wi th orthog-onality constraints'}, {'authors': ['K. S. Kakaria B. L. de Bivort'], 'title': 'Ring attractor dynami cs emergefrom a spiking model of the entire protocerebral bridge'}]}

# %%
os.chdir("../")



transformed_list = []


for pdf_filename, pdf_data in data_dict.items():
    
    title = pdf_data['title']
    authors = pdf_data['authors']
    doi = pdf_data['doi']
    references = pdf_data['references']

    
    main_author = authors[0]

    
    co_authors = authors[1:]

    
    cite_count = sum(1 for entry in data_dict.values() if title in entry['title'])

    
    published_article_count = sum(1 for entry in data_dict.values() if main_author in entry['authors'])

    
    all_titles = [entry['title'] for entry in data_dict.values()] + [ref['title'] for ref in references]
    total_cite_count = sum(1 for entry_title in all_titles if title in entry_title)

    
    transformed_entry = {
        "author": main_author,
        "title": title,
        "coAuthor": co_authors,
        "citeCount": total_cite_count,
        "references": {ref['title']: ref['authors'] for ref in references},
        "doi": doi,
        "publishedArticle": published_article_count
    }

    
    transformed_list.append(transformed_entry)


output_file = 'DLdata_scraped.json'
with open(output_file, 'w') as json_file:
    json.dump(transformed_list, json_file, indent=2)
