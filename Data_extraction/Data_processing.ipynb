# %%
import os
import glob

latest_versions = {}

os.chdir("../Raw_data")

pdf_files = glob.glob("*.pdf")

for pdf_file in pdf_files:
    base_filename = pdf_file[:-6] 

    version_number = int(pdf_file[-5]) 

    if base_filename not in latest_versions or version_number > latest_versions[base_filename]:
        latest_versions[base_filename] = version_number

for pdf_file in pdf_files:
    base_filename = pdf_file[:-6]
    version_number = int(pdf_file[-5])

    if version_number < latest_versions[base_filename]:
        os.remove(pdf_file)
        print(f"Deleted old version: {pdf_file}")

# %%
import os
import glob
import PyPDF2
import json

import re

def extract_references_content(text):
    
    pattern = r'R\s*E\s*F\s*E\s*R\s*E\s*N\s*C\s*E\s*S(.+)'

    
    match = re.search(pattern, text, re.DOTALL | re.IGNORECASE)

    
    if match:
        
        return match.group(1).strip()
    else:
        return None

def extract_references(text):
    
    references_content = extract_references_content(text)

    
    if references_content:
        
        pattern = r'\[\d+\]\s*([^“]+?)“([^”]+)”'

        
        matches = re.findall(pattern, references_content, re.DOTALL)

        
        cleaned_matches = []
        for authors, title in matches:
            
            authors_list = [author.strip().replace(',', '') for author in authors.split(',')]

            
            authors_list = [author.replace(' and ', ' ').replace(' et al.', '') for author in authors_list]

            
            authors_list = list(filter(None, authors_list))

            
            cleaned_title = title.replace('\n', '').rstrip(',')

            cleaned_matches.append({'authors': authors_list, 'title': cleaned_title.strip()})

        return cleaned_matches
    else:
        return None

def extract_information(pdf_file):
    
    with open(pdf_file, 'rb') as file:
        
        pdf_reader = PyPDF2.PdfReader(file)

        
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text = page.extract_text()

            
            references = extract_references(text)

        
        file.close()
        return references

def process_remaining_pdfs(raw_data_folder, json_file_path):
    
    pdf_metadata_dict = {}

    
    with open(json_file_path, 'r', encoding='utf-8') as json_file:
        for line in json_file:
            
            try:
                data = json.loads(line)
            except json.JSONDecodeError:
                print("Error decoding JSON:", line)
                continue  

            
            pdf_id = data.get('id', '')
            if not pdf_id.startswith("2003"):
                continue  

            
            pdf_filename = pdf_id + ".pdf"

            
            title, authors_parsed, doi = extract_metadata_from_json(data)

            
            pdf_metadata_dict[pdf_filename] = {
                'title': title,
                'authors': authors_parsed,
                'doi': doi
            }

    
    os.chdir(raw_data_folder)

    
    pdf_files = glob.glob("*.pdf")

    
    for pdf_file in pdf_files:
        
        pdf_filename = os.path.splitext(pdf_file)[0][:-2]+".pdf"

        
        if pdf_filename in pdf_metadata_dict:
            
            references = extract_information(pdf_file)

            
            metadata = pdf_metadata_dict[pdf_filename]
            title = metadata['title']
            authors_parsed = metadata['authors']
            doi = metadata['doi']
            pdf_metadata_dict['references'] = references


    return pdf_metadata_dict
    

def extract_metadata_from_json(data):
    
    title = data.get('title', '')
    authors_parsed = data.get('authors_parsed', [])
    doi = data.get('doi', '')

    authors_parsed = [f"{author[1]} {author[0]}" if len(author) > 1 else author[0] for author in authors_parsed]

    return title, authors_parsed, doi


raw_data_folder = "../Raw_data"


json_file_path = "../arxiv_metadata_dump//arxiv-metadata-oai-snapshot.json"


data_dict = process_remaining_pdfs(raw_data_folder, json_file_path)
# Out:
# 2003.00958.pdf
# Title: Score Engineered Logistic Regression
# Authors Parsed: ['Bruce Hoadley']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00600.pdf
# Title: A Lobster-inspired Hybrid Actuator With Rigid and Soft Components
# Authors Parsed: ['Yaohui Chen', 'Sing Le', 'Qiao Chu Tan', 'Oscar Lau', 'Chaoyang Song']
# DOI: 10.1115/detc2017-68082
# References: None
# --------------------------------------------------
# 2003.01081.pdf
# Title: On-the-fly Optimization of Parallel Computation of Symbolic Symplectic
#   Invariants
# Authors Parsed: ['Joseph Ben Geloun', 'Camille Coti', 'Allen D. Malony']
# DOI: None
# References: []
# --------------------------------------------------
# 2003.00667.pdf
# Title: MVP: Unified Motion and Visual Self-Supervised Learning for Large-Scale
#   Robotic Navigation
# Authors Parsed: ['Marvin Chancán', 'Michael Milford']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00309.pdf
# Title: Possible Lattice and Charge Order in CuxBi2Te2Se
# Authors Parsed: ['Yanan Li', 'Nathaniel P. Smith', 'William Rexhausen', 'Marvin A Schofield', 'Prasenjit Guptasarma']
# DOI: 10.1088/2515-7639/ab5bfe
# References: None
# --------------------------------------------------
# 2003.00359.pdf
# Title: Contextual-Bandit Based Personalized Recommendation with Time-Varying
#   User Interests
# Authors Parsed: ['Xiao Xu', 'Fang Dong', 'Yanghua Li', 'Shaojian He', 'Xin Li']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00164.pdf
# Title: Towards Using Count-level Weak Supervision for Crowd Counting
# Authors Parsed: ['Yinjie Lei', 'Yan Liu', 'Pingping Zhang', 'Lingqiao Liu']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00969.pdf
# Title: Searching for Fast Neutrino Flavor Conversion Modes in Core-collapse
#   Supernova Simulations
# Authors Parsed: ['Sajad Abbar']
# DOI: 10.1088/1475-7516/2020/05/027
# References: None
# --------------------------------------------------
# 2003.00608.pdf
# Title: MBGD-RDA Training and Rule Pruning for Concise TSK Fuzzy Regression
#   Models
# Authors Parsed: ['Dongrui Wu']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00794.pdf
# Title: Quantum Refrigeration with Indefinite Causal Order
# Authors Parsed: ['David Felce', 'Vlatko Vedral']
# DOI: 10.1103/PhysRevLett.125.070603
# References: None
# --------------------------------------------------
# 2003.01315.pdf
# Title: Width estimate and doubly warped product
# Authors Parsed: ['Jintian Zhu']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00098.pdf
# Title: Landscape of coexisting excitonic states in the insulating single-layer
#   cuprates and nickelates
# Authors Parsed: ['Christopher Lane', 'Jian-Xin Zhu']
# DOI: 10.1103/PhysRevB.101.155135
# References: None
# --------------------------------------------------
# 2003.00129.pdf
# Title: Determination of Latent Dimensionality in International Trade Flow
# Authors Parsed: ['Duc P. Truong', 'Erik Skau', 'Vladimir I. Valtchinov', 'Boian S. Alexandrov']
# DOI: 10.1088/2632-2153/aba9ee
# References: None
# --------------------------------------------------
# 2003.01822.pdf
# Title: Implicitly Defined Layers in Neural Networks
# Authors Parsed: ['Qianggong Zhang', 'Yanyang Gu', 'Michalkiewicz Mateusz', 'Mahsa Baktashmotlagh', 'Anders Eriksson']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00241.pdf
# Title: In search of biomarkers and the ideotype of barley tolerant to water
#   scarcity
# Authors Parsed: ['Pawel Krajewski', 'Piotr Kachlicki', 'Anna Piasecka', 'Maria Surma', 'Anetta Kuczynska', 'Krzysztof Mikolajczak', 'Piotr Ogrodowicz', 'Aneta Sawikowska', 'Hanna Cwiek-Kupczynska', 'Maciej Stobiecki', 'Pawel Rodziewicz', 'Lukasz Marczak']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01609.pdf
# Title: SELD-TCN: Sound Event Localization & Detection via Temporal
#   Convolutional Networks
# Authors Parsed: ['Karim Guirguis', 'Christoph Schorn', 'Andre Guntoro', 'Sherif Abdulatif', 'Bin Yang']
# DOI: 10.23919/Eusipco47968.2020.9287716
# References: [{'authors': ['T. Marques', 'L. Thomas', 'S. Martin', 'D. Mellinger', 'J. A Ward', 'D. Moretti', 'D. Harris', 'and P. Tyack'], 'title': 'Estimating animal population density usingpassive acoustics'}, {'authors': ['E. Benetos T. Weyde'], 'title': 'An Efﬁcient Temporally-Constrained Proba-bilistic Model for Multiple-Instrument Music Transcription'}, {'authors': ['T. Heittola', 'A. Klapuri', 'and T. Virtanen'], 'title': 'Musical Instrument Recog-nition in Polyphonic Audio Using Source-Filter Model for SoundSeparation.'}, {'authors': ['D. Rossiter', 'G. Lam', 'and B. Mak'], 'title': 'Automatic Audio Indexing and AudioPlayback Speed Control as Tools for Language Learning'}, {'authors': ['R. Roden', 'S. Gerlach', 'N. Moritz', 'S. Weinzierl', 'and S. Goetze'], 'title': 'On soundsource localization of speech signals using deep neural networks'}, {'authors': ['X. Xiao', 'S. Zhao', 'X. Zhong', 'D. Jones', 'E. Chng', 'and H. Li'], 'title': 'A learning-based approach to direction of arrival estimation in noisy and reverberantenvironments'}, {'authors': ['R. Takeda K. Komatani'], 'title': 'Discriminative multiple sound sourcelocalization based on deep neural networks using independent locationmodel'}, {'authors': ['A. Nugraha', 'A. Liutkus', 'and E. Vincent', 'Deep Neural Network Based\nMultichannel Audio Source Separation', 'Jan. 2017.\n[9] F. Vesperini', 'P. Vecchiotti', 'E. Principi', 'S. Squartini', 'and F. Piazza'], 'title': 'Aneural network based algorithm for speaker localization in a multi-roomenvironment'}, {'authors': ['S. Chakrabarty E. Habets'], 'title': 'Broadband DOA estimation usingconvolutional neural networks trained with noise signals'}, {'authors': ['S. Adavanne', 'A. Politis', 'and T. Virtanen'], 'title': 'Direction of Arrival Estima-tion for Multiple Sound Sources Using Convolutional Recurrent NeuralNetwork'}, {'authors': ['J. Schrder', 'B. Cauchi', 'M. Schdler', 'N. Moritz', 'K. Adiloglu', 'J. Anemller', 'S. Doclo', 'B. Kollmeier', 'and S. Goetze'], 'title': 'Acoustic event detection usingsignal enhancement and spectro-temporal feature extraction'}, {'authors': ['T. Heittola', 'A. Mesaros', 'A. Eronen', 'and T. Virtanen'], 'title': 'Context-dependentsound event detection'}, {'authors': ['T. Heittola', 'A. Mesaros', 'T. Virtanen', 'and A. Eronen'], 'title': 'Sound EventDetection in Multisource Environments Using Source Separation'}, {'authors': ['S. Innami H. Kasai'], 'title': 'NMF-based environmental sound source sep-aration using time-variant gain features'}, {'authors': ['A. Dessein', 'A. Cont', 'and G. Lemaitre'], 'title': 'Real-Time Detection of Over-lapping Sound Events with Non-Negative Matrix Factorization'}, {'authors': ['T. Komatsu', 'T. Toizumi', 'R. Kondo', 'and Y . Senda'], 'title': 'Acoustic EventDetection Method Using Semi-Supervised Non-Negative Matrix Fac-torization with Mixtures of Local Dictionaries'}, {'authors': ['H. Zhang', 'I. Mcloughlin', 'and Y . Song'], 'title': 'Robust sound event recognitionusing convolutional neural networks'}, {'authors': ['H. Phan', 'L. Hertel', 'M. Maa', 'and A. Mertins'], 'title': 'Robust Audio EventRecognition with 1-Max Pooling Convolutional Neural Networks'}, {'authors': ['P. Zinemanas', 'P. Cancela', 'and M. Rocamora'], 'title': 'End-to-end ConvolutionalNeural Networks for Sound Event Detection in Urban Environments'}, {'authors': ['S. Adavanne', 'G. Parascandolo', 'P. Pertil', 'T. Heittola', 'and T. Virtanen'], 'title': 'Sound Event Detection in Multichannel Audio Using Spatial andHarmonic Features'}, {'authors': ['T. Hayashi', 'S. Watanabe', 'T. Toda', 'T. Hori', 'J. Le Roux', 'and K. Takeda'], 'title': 'Duration-Controlled LSTM for Polyphonic Sound Event Detection'}, {'authors': ['M. Zhrer F. Pernkopf'], 'title': 'Virtual Adversarial Training and Data Aug-mentation for Acoustic Event Detection with Gated Recurrent NeuralNetworks'}, {'authors': ['E. Cakir', 'G. Parascandolo', 'T. Heittola', 'H. Huttunen', 'and T. Virtanen'], 'title': 'Convolutional Rec ...
# --------------------------------------------------
# 2003.01188.pdf
# Title: Quasinormal modes, stability and shadows of a black hole in the 4D
#   Einstein-Gauss-Bonnet gravity
# Authors Parsed: ['R. A. Konoplya', 'A. F. Zinhailo']
# DOI: 10.1140/epjc/s10052-020-08639-8
# References: None
# --------------------------------------------------
# 2003.01358.pdf
# Title: Calculating Renyi Entropies with Neural Autoregressive Quantum States
# Authors Parsed: ['Zhaoyou Wang', 'Emily J. Davis']
# DOI: 10.1103/PhysRevA.102.062413
# References: None
# --------------------------------------------------
# 2003.00827.pdf
# Title: CheXclusion: Fairness gaps in deep chest X-ray classifiers
# Authors Parsed: ['Laleh Seyyed-Kalantari', 'Guanxiong Liu', 'Matthew McDermott', 'Irene Y. Chen', 'Marzyeh Ghassemi']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00253.pdf
# Title: Impact of Interparticle Interaction on Thermodynamics of Nano-Channel
#   Transport of Two Species
# Authors Parsed: ['Wolfgang Rudolf Bauer']
# DOI: 10.3390/e22040376
# References: None
# --------------------------------------------------
# 2003.01807.pdf
# Title: Horizons Protect Church-Turing
# Authors Parsed: ['Leonard Susskind']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01247.pdf
# Title: Iterative Averaging in the Quest for Best Test Error
# Authors Parsed: ['Diego Granziol', 'Xingchen Wan', 'Samuel Albanie', 'Stephen Roberts']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00668.pdf
# Title: Improved Gilbert-Varshamov Bound for Entanglement-Assisted Asymmetric
#   Quantum Error Correction by Symplectic Orthogonality
# Authors Parsed: ['Ryutaroh Matsumoto']
# DOI: 10.1109/TQE.2020.2978454
# References: None
# --------------------------------------------------
# 2003.01817.pdf
# Title: Unveiling Defect-Mediated Carrier Dynamics in Monolayer Semiconductors
#   by Spatiotemporal Microwave Imaging
# Authors Parsed: ['Zhaodong Chu', 'Chun-Yuan Wang', 'Jiamin Quan', 'Chenhui Zhang', 'Chao Lei', 'Ali Han', 'Xuejian Ma', 'Hao-Ling Tang', 'Dishan Abeysinghe', 'Matthew Staab', 'Xixiang Zhang', 'Allan H. MacDonald', 'Vincent Tung', 'Xiaoqin Li', 'Chih-Kang Shih', 'Keji Lai']
# DOI: 10.1073/pnas.2004106117
# References: None
# --------------------------------------------------
# 2003.01086.pdf
# Title: Predictive Coding for Locally-Linear Control
# Authors Parsed: ['Rui Shu', 'Tung Nguyen', 'Yinlam Chow', 'Tuan Pham', 'Khoat Than', 'Mohammad Ghavamzadeh', 'Stefano Ermon', 'Hung H. Bui']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01311.pdf
# Title: Mean equicontinuity and mean sensitivity on cellular automata
# Authors Parsed: ['Luguis de los Santos Baños', 'Felipe García-Ramos']
# DOI: 10.1017/etds.2020.108
# References: None
# --------------------------------------------------
# 2003.01774.pdf
# Title: Directional Compliance in Obstacle-Aided Navigation for Snake Robots
# Authors Parsed: ['Tianyu Wang', 'Julian Whitman', 'Matthew Travers', 'Howie Choset']
# DOI: 10.23919/ACC45564.2020.9148021
# References: [{'authors': ['T. Kano', 'R. Yoshizawa', 'and A. Ishiguro'], 'title': 'Tegotae-based decentralisedcontrol scheme for autonomous gait transition of snake-like robots'}, {'authors': ['F. Sanﬁlippo', 'J. Azpiazu', 'G. Maraﬁoti', 'A. Transeth', 'Ø. Stavdahl', 'and P. Liljeb ¨ack'], 'title': 'Perception-driven obstacle-aided locomotion forsnake robots: the state of the art, challenges and possibilities'}, {'authors': ['M. Travers', 'J. Whitman', 'and H. Choset'], 'title': 'Shape-based coordination inlocomotion control'}, {'authors': ['J. Whitman', 'F. Ruscelli', 'M. Travers', 'and H. Choset'], 'title': 'Shape-basedcompliant control with variable coordination centralization on a snakerobot'}, {'authors': ['B. C. Jayne'], 'title': 'Muscular mechanisms of snake locomotion: an elec-tromyographic study of lateral undulation of the ﬂorida banded watersnake (nerodia fasciata) and the yellow rat snake (elaphe obsoleta)'}, {'authors': ['P. E. Schiebel', 'J. M. Rieser', 'A. M. Hubbard', 'L. Chen', 'D. Z. Rocklin', 'and D. I. Goldman'], 'title': 'Mechanical diffraction reveals the role of passivedynamics in a slithering snake'}, {'authors': ['H. Astley', 'J. Mendelson', 'and D. Goldman'], 'title': 'Side-Impact Collision:Obstacle Negotiation Mechanics in Sidewinding Snakes'}, {'authors': ['M. Travers', 'A. Ansari', 'and H. Choset'], 'title': 'A dynamical systems approachto obstacle navigation for a series-elastic hexapod robot'}, {'authors': ['S. Hirose'], 'title': 'Biologically inspired robots'}, {'authors': ['M. Tesch', 'K. Lipkin', 'I. Brown', 'R. Hatton', 'A. Peck', 'J. Rembisz', 'and H. Choset'], 'title': 'Parameterized and scripted gaits for modular snakerobots'}, {'authors': ['C. Ott', 'R. Mukherjee', 'and Y . Nakamura'], 'title': 'Uniﬁed impedance and ad-mittance control'}, {'authors': ['D. Rollinson', 'Y . Bilgen', 'B. Brown', 'F. Enner', 'S. Ford', 'C. Layton', 'J. Rembisz', 'M. Schwerin', 'A. Willig', 'P. Velagapudi', 'et al.'], 'title': 'Designand architecture of a series elastic snake robot'}, {'authors': ['G. A. Pratt M. M. Williamson'], 'title': 'Series elastic actuators'}]
# --------------------------------------------------
# 2003.00317.pdf
# Title: A Bayesian approach to tissue-fraction estimation for oncological PET
#   segmentation
# Authors Parsed: ['Ziping Liu', 'Joyce C. Mhlanga', 'Richard Laforest', 'Paul-Robert Derenoncourt', 'Barry A. Siegel', 'Abhinav K. Jha']
# DOI: 10.1088/1361-6560/ac01f4
# References: []
# --------------------------------------------------
# 2003.01000.pdf
# Title: Robust Policy Search for Robot Navigation with Stochastic Meta-Policies
# Authors Parsed: ['Javier Garcia-Barcos', 'Ruben Martinez-Cantin']
# DOI: None
# References: [{'authors': ['R. J. Williams'], 'title': 'Simple statistical gradient-following algorithms forconnectionist reinforcement learning'}, {'authors': ['M. Deisenroth', 'G. Neumann', 'and J. Peters'], 'title': 'A survey on policy searchfor robotics'}, {'authors': ['J. Peters S. Schaal'], 'title': 'Policy gradient methods for robotics'}, {'authors': ['N. Kohl P. Stone'], 'title': 'Policy gradient reinforcement learning for fastquadrupedal locomotion'}, {'authors': ['S. Levine P. Abbeel'], 'title': 'Learning neural network policies withguided policy search under unknown dynamics'}, {'authors': ['R. Martinez-Cantin', 'N. de Freitas', 'A. Doucet', 'and J. A. Castellanos'], 'title': 'Active policy learning for robot planning and exploration underuncertainty'}, {'authors': ['R. Martinez-Cantin', 'N. de Freitas', 'E. Brochu', 'J. Castellanos', 'and\nA. Doucet'], 'title': 'A Bayesian exploration-exploitation approach for optimalonline sensing and planning with a visually guided mobile robot.'}, {'authors': ['B. Shahriari', 'K. Swersky', 'Z. Wang', 'R. Adams', 'and N. de Freitas'], 'title': 'Taking the human out of the loop: A review of Bayesian optimization'}, {'authors': ['D. Lizotte', 'T. Wang', 'M. Bowling', 'and D. Schuurmans.'], 'title': 'Automaticgait optimization with gaussian process regression'}, {'authors': ['R. Calandra', 'A. Seyfarth', 'J. Peters', 'and M. Deisenroth'], 'title': 'Bayesian opti-mization for learning gaits under uncertainty'}, {'authors': ['A. Rai', 'R. Antonova', 'F. Meier', 'and C. G. Atkeson'], 'title': 'Using simulation toimprove sample-efﬁciency of bayesian optimization for bipedal robots.'}, {'authors': ['M. Tesch', 'J. Schneider', 'and H. Choset'], 'title': 'Adapting control policiesfor expensive systems to changing environments'}, {'authors': ['S. R. Kuindersma', 'R. A. Grupen', 'and A. G. Barto'], 'title': 'Variable risk controlvia stochastic optimization'}, {'authors': ['R. Marchant F. Ramos'], 'title': 'Bayesian optimisation for informativecontinuous path planning'}, {'authors': ['J. Nogueira', 'R. Martinez-Cantin', 'A. Bernardino', 'and L. Jamone'], 'title': 'Unscented bayesian optimization for safe robot grasping'}, {'authors': ['C. Daniel', 'O. Kroemer', 'M. Viering', 'J. Metz', 'and J. Peters'], 'title': 'Activereward learning with a novel acquisition function'}, {'authors': ['A. Cully', 'J. Clune', 'D. Tarapore', 'and J. B. Mouret'], 'title': 'Robots that canadapt like animals'}, {'authors': ['D. R. Jones', 'M. Schonlau', 'and W. J. Welch'], 'title': 'Efﬁcient globaloptimization of expensive black-box functions'}, {'authors': ['Y . Sui', 'A. Gotovos', 'J. Burdick', 'and A. Krause'], 'title': 'Safe exploration foroptimization with gaussian processes'}, {'authors': ['R. Martinez-Cantin', 'K. Tee', 'and M. McCourt'], 'title': 'Practical bayesianoptimization in the presence of outliers'}, {'authors': ['R. Martinez-Cantin'], 'title': 'Bayesian optimization with adaptive kernels forrobot control'}, {'authors': ['J. Garcia-Barcos R. Martinez-Cantin'], 'title': 'Fully distributed bayesianoptimization with stochastic policies'}, {'authors': ['R. Martinez-Cantin'], 'title': 'Funneled Bayesian optimization for design, tuningand control of autonomous systems'}, {'authors': ['D. Huang', 'T. T. Allen', 'W. I. Notz', 'and N. Zheng'], 'title': 'Global optimizationof stochastic black-box systems via sequential kriging meta-models'}, {'authors': ['J. Mockus', 'V . Tiesis', 'and A. Zilinskas'], 'title': 'The application of Bayesianmethods for seeking the extremum'}, {'authors': ['C. Rasmussen C. Williams', 'Gaussian Processes for Machine\nLearning . The MIT Press', '2006.\n[27] J. Snoek', 'H. Larochelle', 'and R. Adams'], 'title': 'Practical Bayesian optimiza-tion of machine learning algorithms'}, {'authors': ['A. D. Bull'], 'title': 'Convergence rates of efﬁcient global optimizationalgorithms'}, {'authors': ['J. Castanheira', 'P. Vicente', 'R. Martinez-Cantin', 'L. Jamone', 'and\nA. Bernardino'], 'titl ...
# --------------------------------------------------
# 2003.01137.pdf
# Title: UV line driven disc wind as the origin of ultrafast outflows in AGN
# Authors Parsed: ['Misaki Mizumoto', 'Mariko Nomura', 'Chris Done', 'Ken Ohsuga', 'Hirokazu Odaka']
# DOI: 10.1093/mnras/staa3282
# References: None
# --------------------------------------------------
# 2003.00641.pdf
# Title: VAE/WGAN-Based Image Representation Learning For Pose-Preserving
#   Seamless Identity Replacement In Facial Images
# Authors Parsed: ['Hiroki Kawai', 'Jiawei Chen', 'Prakash Ishwar', 'Janusz Konrad']
# DOI: 10.1109/MLSP.2019.8918926
# References: None
# --------------------------------------------------
# 2003.01339.pdf
# Title: Gamma-ray Emission Properties of Four Bright Fermi-LAT AGNs:
#   Implications on Emission Processes
# Authors Parsed: ['Pankaj Kushwaha', 'Atreyee Sinha', 'Ranjeev Misra', 'K. P. Singh', 'E. M. de Gouveia Dal Pino']
# DOI: None
# References: []
# --------------------------------------------------
# 2003.01131.pdf
# Title: When Gas Dynamics Decouples from Galactic Rotation: Characterizing ISM
#   Circulation in Disk Galaxies
# Authors Parsed: ['Jose Utreras', 'Guillermo A. Blanc', 'Andres Escala', 'Sharon Meidt', 'Eric Emsellem', 'Frank Bigiel', 'Simon C. O. Glover', 'Jonathan Henshaw', 'Alex Hygate', 'J. M. Diederik Kruijssen', 'Erik Rosolowsky', 'Eva Schinnerer', 'Andreas Schruba']
# DOI: 10.3847/1538-4357/ab7a95
# References: None
# --------------------------------------------------
# 2003.00506.pdf
# Title: Predictive $S_4$ flavon model with $\text{TM}_1$ mixing and baryogenesis
#   through leptogenesis
# Authors Parsed: ['Mainak Chakraborty', 'R. Krishnan', 'Ambar Ghosal']
# DOI: 10.1007/JHEP09(2020)025
# References: None
# --------------------------------------------------
# 2003.00929.pdf
# Title: Intrinsic entropy for generalized quasimetric semilattices
# Authors Parsed: ['Ilaria Castellano', 'Dikran Dikranjan', 'Domenico Freni', 'Anna Giordano Bruno', 'Daniele Toller']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01255.pdf
# Title: Height Gap Conjectures, $D$-Finiteness, and Weak Dynamical Mordell-Lang
# Authors Parsed: ['Jason P. Bell', 'Fei Hu', 'Matthew Satriano']
# DOI: 10.1007/s00208-020-02062-w
# References: None
# --------------------------------------------------
# 2003.01130.pdf
# Title: Improved Simulation of Quantum Circuits by Fewer Gaussian Eliminations
# Authors Parsed: ['Lucas Kocia', 'Mohan Sarovar']
# DOI: 10.1103/PhysRevA.103.022603
# References: None
# --------------------------------------------------
# 2003.00521.pdf
# Title: Surface Effects in Superconductors with Corners
# Authors Parsed: ['Michele Correggi']
# DOI: 10.1007/s40574-020-00236-7
# References: None
# --------------------------------------------------
# 2003.00111.pdf
# Title: Phonons become chiral in the pseudogap phase of cuprates
# Authors Parsed: ['G. Grissonnanche', 'S. Thériault', 'A. Gourgout', 'M. -E. Boulanger', 'E. Lefrançois', 'A. Ataei', 'F. Laliberté', 'M. Dion', 'J. -S. Zhou', 'S. Pyon', 'T. Takayama', 'H. Takagi', 'N. Doiron-Leyraud', 'L. Taillefer']
# DOI: 10.1038/s41567-020-0965-y
# References: None
# --------------------------------------------------
# 2003.01602.pdf
# Title: Time-Resolved Momentum Microscopy with a 1 MHz High-Harmonic Extreme
#   Ultraviolet Beamline
# Authors Parsed: ['M. Keunecke', 'C. Möller', 'D. Schmitt', 'H. Nolte', 'G. S. M. Jansen', 'M. Reutzel', 'M. Gutberlet', 'G. Halasi', 'D. Steil', 'S. Steil', 'S. Mathias']
# DOI: 10.1063/5.0006531
# References: None
# --------------------------------------------------
# 2003.00433.pdf
# Title: Fully Asynchronous Policy Evaluation in Distributed Reinforcement
#   Learning over Networks
# Authors Parsed: ['Xingyu Sha', 'Jiaqi Zhang', 'Keyou You', 'Kaiqing Zhang', 'Tamer Başar']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00261.pdf
# Title: Synchrotron radiation in odd dimensions
# Authors Parsed: ["D. V. Gal'tsov", 'M. Khlopunov']
# DOI: 10.1103/PhysRevD.101.084054
# References: None
# --------------------------------------------------
# 2003.00854.pdf
# Title: On Abel-Jacobi maps of moduli of parabolic bundles over a curve
# Authors Parsed: ['Sujoy Chakraborty']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01325.pdf
# Title: Resilience of the superradiant phase against $\mathbf {A^2}$ effects in
#   the quantum Rabi dimer
# Authors Parsed: ['Yimin Wang', 'Maoxin Liu', 'Wen-Long You', 'Stefano Chesi', 'Hong-Gang Luo', 'Hai-Qing Lin']
# DOI: 10.1103/PhysRevA.101.063843
# References: None
# --------------------------------------------------
# 2003.00731.pdf
# Title: Instability and evolution of the magnetic ground state in metallic
#   perovskites GdRh$_3$C$_{1-x}$B$_x$
# Authors Parsed: ['Abhishek Pandey', 'A. K. Singh', 'Shovan Dan', 'K. Ghosh', 'I. Das', 'S. Tripathi', 'U. Kumar', 'R. Ranganathan', 'D. C. Johnston', 'Chandan Mazumdar']
# DOI: 10.1103/PhysRevMaterials.4.084411
# References: None
# --------------------------------------------------
# 2003.01208.pdf
# Title: Unveiling of the mechanisms of acoustic streaming induced by sharp edges
# Authors Parsed: ['Chuanyu Zhang', 'Xiaofeng Guo', 'Laurent Royon', 'Philippe Brunet']
# DOI: 10.1103/PhysRevE.102.043110
# References: None
# --------------------------------------------------
# 2003.00529.pdf
# Title: ZoomNet: Part-Aware Adaptive Zooming Neural Network for 3D Object
#   Detection
# Authors Parsed: ['Zhenbo Xu', 'Wei Zhang', 'Xiaoqing Ye', 'Xiao Tan', 'Wei Yang', 'Shilei Wen', 'Errui Ding', 'Ajin Meng', 'Liusheng Huang']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00459.pdf
# Title: A BeiDou Signal Acquisition Approach Using Variable Length Data
#   Accumulation based on Signal Delay and Multiplication
# Authors Parsed: ['Menghuan Yang', 'Hong Wu', 'Qiqi Wang', 'Yingxin Zhao', 'Zhiyang Liu']
# DOI: 10.3390/s20051309
# References: None
# --------------------------------------------------
# 2003.01343.pdf
# Title: Improving Candidate Generation for Low-resource Cross-lingual Entity
#   Linking
# Authors Parsed: ['Shuyan Zhou', 'Shruti Rijhwani', 'John Wieting', 'Jaime Carbonell', 'Graham Neubig']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00439.pdf
# Title: Differential Evolution with Individuals Redistribution for Real
#   Parameter Single Objective Optimization
# Authors Parsed: ['Chengjun Li', 'Yang Li']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00779.pdf
# Title: Data-Driven Control of Unknown Systems: A Linear Programming Approach
# Authors Parsed: ['Alexandros Tanzanakis', 'John Lygeros']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01604.pdf
# Title: Self-Supervised Graph Representation Learning via Global Context
#   Prediction
# Authors Parsed: ['Zhen Peng', 'Yixiang Dong', 'Minnan Luo', 'Xiao-Ming Wu', 'Qinghua Zheng']
# DOI: None
# References: []
# --------------------------------------------------
# 2003.00159.pdf
# Title: When does the onset of multiple stellar populations in star clusters
#   occur-III: No evidence of significant chemical variations in main-sequence
#   stars of NGC 419
# Authors Parsed: ['Chengyuan Li', 'Yue Wang', 'Baitian Tang', 'Antonino P. Milone', 'Yujiao Yang', 'Xin Ji']
# DOI: 10.3847/1538-4357/ab7b64
# References: None
# --------------------------------------------------
# 2003.00994.pdf
# Title: Machine learning spectral indicators of topology
# Authors Parsed: ['Nina Andrejevic', 'Jovana Andrejevic', 'B. Andrei Bernevig', 'Nicolas Regnault', 'Fei Han', 'Gilberto Fabbris', 'Thanh Nguyen', 'Nathan C. Drucker', 'Chris H. Rycroft', 'Mingda Li']
# DOI: 10.1002/adma.202204113
# References: None
# --------------------------------------------------
# 2003.01209.pdf
# Title: Log orthogonal functions: approximation properties and applications
# Authors Parsed: ['Sheng Chen', 'Jie Shen']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00651.pdf
# Title: Global Context-Aware Progressive Aggregation Network for Salient Object
#   Detection
# Authors Parsed: ['Zuyao Chen', 'Qianqian Xu', 'Runmin Cong', 'Qingming Huang']
# DOI: None
# References: []
# --------------------------------------------------
# 2003.01436.pdf
# Title: Learning to Generate Time Series Conditioned Graphs with Generative
#   Adversarial Nets
# Authors Parsed: ['Shanchao Yang', 'Jing Liu', 'Kai Wu', 'Mingming Li']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00415.pdf
# Title: Advanced kNN: A Mature Machine Learning Series
# Authors Parsed: ['Muhammad Asim', 'Muaaz Zakria']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00856.pdf
# Title: Triangle-Net: Towards Robustness in Point Cloud Learning
# Authors Parsed: ['Chenxi Xiao', 'Juan Wachs']
# DOI: 10.1109/WACV48630.2021.00087
# References: None
# --------------------------------------------------
# 2003.00831.pdf
# Title: Character Segmentation in Asian Collector's Seal Imprints: An Attempt to
#   Retrieval Based on Ancient Character Typeface
# Authors Parsed: ['Kangying Li', 'Biligsaikhan Batjargal', 'Akira Maeda']
# DOI: None
# References: []
# --------------------------------------------------
# 2003.01249.pdf
# Title: Hidden Cost of Randomized Smoothing
# Authors Parsed: ['Jeet Mohapatra', 'Ching-Yun Ko', ' Tsui-Wei', ' Weng', 'Sijia Liu', 'Pin-Yu Chen', 'Luca Daniel']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00622.pdf
# Title: Extremal problems for hypergraph blowups of trees
# Authors Parsed: ['Zoltán Füredi', 'Tao Jiang', 'Alexandr Kostochka', 'Dhruv Mubayi', 'Jacques Verstraëte']
# DOI: None
# References: []
# --------------------------------------------------
# 2003.01451.pdf
# Title: The Hasse Norm Principle in Global Function Fields
# Authors Parsed: ['Adelina Mânzăţeanu', 'Rachel Newton', 'Ekin Ozman', 'Nicole Sutherland', 'Rabia Gülşah Uysal']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01336.pdf
# Title: An advanced meshless approach for the high-dimensional multi-term
#   time-space-fractional PDEs on convex domains
# Authors Parsed: ['Xiaogang Zhu', 'Yufeng Nie', 'Jungang Wang', 'Zhanbin Yuan']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01071.pdf
# Title: A census of the pulsar population observed with the international LOFAR
#   station FR606 at low frequencies (25-80~MHz)
# Authors Parsed: ['L. Bondonneau', 'J. -M. Grießmeier', 'G. Theureau', 'A. V. Bilous', 'V. I. Kondratiev', 'M. Serylak', 'M. J. Keith', 'A. G. Lyne']
# DOI: 10.1051/0004-6361/201936829
# References: None
# --------------------------------------------------
# 2003.01144.pdf
# Title: Higher-order topological band structures
# Authors Parsed: ['Luka Trifunovic', 'Piet W. Brouwer']
# DOI: 10.1002/pssb.202000090
# References: []
# --------------------------------------------------
# 2003.00598.pdf
# Title: Data Normalization for Bilinear Structures in High-Frequency Financial
#   Time-series
# Authors Parsed: ['Dat Thanh Tran', 'Juho Kanniainen', 'Moncef Gabbouj', 'Alexandros Iosifidis']
# DOI: None
# References: [{'authors': ['D. T. Tran', 'A. Iosiﬁdis', 'J. Kanniainen', 'and M. Gabbouj'], 'title': 'T empo-ral attention-augmented bilinear network for ﬁnancial tim e-series dataanalysis'}, {'authors': ['Z. Zhang', 'S. Zohren', 'and S. Roberts'], 'title': 'Deeplob: Deep convo lutionalneural networks for limit order books'}, {'authors': ['N. Passalis', 'A. Tefas', 'J. Kanniainen', 'M. Gabbouj', 'and A. I osiﬁdis'], 'title': 'Temporal bag-of-features learning for predicting mid pri ce movementsusing high frequency limit order book data'}, {'authors': ['D. T. Tran', 'M. Gabbouj', 'and A. Iosiﬁdis'], 'title': 'Multilinear cla ss-speciﬁcdiscriminant analysis'}, {'authors': ['D. T. Tran', 'M. Magris', 'J. Kanniainen', 'M. Gabbouj', 'and A. Io siﬁdis'], 'title': 'Tensor representation in high-frequency ﬁnancial data fo r price changeprediction'}, {'authors': ['N. Passalis', 'A. Tsantekidis', 'A. Tefas', 'J. Kanniainen', 'M. Gabbouj', 'and\nA. Iosiﬁdis'], 'title': 'Time-series classiﬁcation using neural bag- of-features'}, {'authors': ['S. Ren', 'K. He', 'R. Girshick', 'and J. Sun'], 'title': 'Faster r-cnn: Towa rds real-timeobject detection with region proposal networks'}, {'authors': ['J. Redmon', 'S. Divvala', 'R. Girshick', 'and A. Farhadi'], 'title': 'You o nly lookonce: Uniﬁed, real-time object detection'}, {'authors': ['A. Iosiﬁdis', 'A. Tefas', 'and I. Pitas'], 'title': 'View-invariant act ion recognitionbased on artiﬁcial neural networks'}, {'authors': ['D. T. Tran', 'A. Iosiﬁdis', 'and M. Gabbouj'], 'title': 'Improving efﬁc iency inconvolutional neural networks with multilinear ﬁlters'}, {'authors': ['D. T. Tran', 'M. Yamac', 'A. Degerli', 'M. Gabbouj', 'and A. Iosiﬁ dis'], 'title': 'Multilinear compressive learning'}, {'authors': ['D. T. Tran', 'M. Gabbouj', 'and A. Iosiﬁdis'], 'title': 'Multilinear co mpressivelearning with prior knowledge'}, {'authors': ['D. Bahdanau', 'K. Cho', 'and Y . Bengio'], 'title': 'Neural machine tran slation byjointly learning to align and translate'}, {'authors': ['J. Devlin', 'M.-W. Chang', 'K. Lee', 'and K. Toutanova'], 'title': 'Bert: Pre-trainingof deep bidirectional transformers for language understan ding'}, {'authors': ['X. Shao'], 'title': 'Self-normalization for time series: a review of recent de-velopments'}, {'authors': ['S. Nayak', 'B. B. Misra', 'and H. S. Behera'], 'title': 'Impact of data no rmalizationon stock index forecasting'}, {'authors': ['A. Ntakaris', 'G. Mirone', 'J. Kanniainen', 'M. Gabbouj', 'and A . Iosiﬁdis'], 'title': 'Feature engineering for mid-price prediction with deep le arning'}, {'authors': ['S. Ioffe C. Szegedy'], 'title': 'Batch normalization: Acceler ating deepnetwork training by reducing internal covariate shift'}, {'authors': ['D. Ulyanov', 'A. Vedaldi', 'and V . Lempitsky'], 'title': 'Instance nor malization: Themissing ingredient for fast stylization'}, {'authors': ['N. Passalis', 'A. Tefas', 'J. Kanniainen', 'M. Gabbouj', 'and A. Iosiﬁdis'], 'title': 'Deepadaptive input normalization for price forecasting using l imit order bookdata'}, {'authors': ['X. Glorot Y . Bengio'], 'title': 'Understanding the difﬁculty o f trainingdeep feedforward neural networks'}, {'authors': ['K. He', 'X. Zhang', 'S. Ren', 'and J. Sun'], 'title': 'Delving deep into rec tiﬁers:Surpassing human-level performance on imagenet classiﬁca tion'}, {'authors': ['A. Ntakaris', 'M. Magris', 'J. Kanniainen', 'M. Gabbouj', 'and A . Iosiﬁdis'], 'title': 'Benchmark dataset for mid-price forecasting of limit orde r book datawith machine learning methods'}, {'authors': ['D. T. Tran', 'J. Kanniainen', 'M. Gabbouj', 'and A. Iosiﬁdis'], 'title': 'Data-drivenneural architecture learning for ﬁnancial time-series for ecasting'}, {'authors': ['A. Tsantekidis', 'N. Passalis', 'A. Tefas', 'J. Kanniainen', 'M . Gabbouj', 'and\nA. Iosiﬁdis'], 'title': 'Forecasting stock prices from the limit order book usingconvolutional neural networks'}, {'authors': ['A. Tsantekidis', 'N. Passalis', 'A. Tefas', 'J. ...
# --------------------------------------------------
# 2003.00728.pdf
# Title: Prediction of Potential Commercially Available Inhibitors against
#   SARS-CoV-2 by Multi-Task Deep Learning Model
# Authors Parsed: ['Fan Hu', 'Jiaxin Jiang', 'Peng Yin']
# DOI: 10.3390/biom12081156
# References: None
# --------------------------------------------------
# 2003.00702.pdf
# Title: Sector Showers for Hadron Collisions
# Authors Parsed: ['Helen Brooks', 'Christian T Preuss', 'Peter Skands']
# DOI: 10.1007/JHEP07(2020)032
# References: None
# --------------------------------------------------
# 2003.00156.pdf
# Title: Superfluid-Normal Quantum Phase Transitions in an Imbalanced Fermi Gas
# Authors Parsed: ['Heron Caldas']
# DOI: 10.1088/1361-6455/ab7078
# References: None
# --------------------------------------------------
# 2003.00411.pdf
# Title: Data Pre-Processing and Evaluating the Performance of Several Data
#   Mining Methods for Predicting Irrigation Water Requirement
# Authors Parsed: ['Mahmood A. Khan', 'Md Zahidul Islam', 'Mohsin Hafeez']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00335.pdf
# Title: Differentiating through the Fr\'echet Mean
# Authors Parsed: ['Aaron Lou', 'Isay Katsman', 'Qingxuan Jiang', 'Serge Belongie', 'Ser-Nam Lim', 'Christopher De Sa']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00008.pdf
# Title: Reduction theory for connections over the formal punctured disc
# Authors Parsed: ['Andres Fernandez Herrero']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01553.pdf
# Title: Did Sequence Dependent Geometry Influence the Evolution of the Genetic
#   Code?
# Authors Parsed: ['Alex Kasman', 'Brenton LeMesurier']
# DOI: 10.1090/conm/746/15001
# References: None
# --------------------------------------------------
# 2003.00538.pdf
# Title: On the Decycling Number of $4$-regular Random Graphs
# Authors Parsed: ['Lyuben Lichev', 'Dieter Mitsche']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01244.pdf
# Title: Universal quivers
# Authors Parsed: ['Sergey Fomin', 'Kiyoshi Igusa', 'Kyungyong Lee']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01054.pdf
# Title: Double Trouble in Double Descent : Bias and Variance(s) in the Lazy
#   Regime
# Authors Parsed: ["Stéphane d'Ascoli", 'Maria Refinetti', 'Giulio Biroli', 'Florent Krzakala']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00386.pdf
# Title: Experimental Evaluation of a Pseudo-Doppler Direction-Finding System for
#   Localizing Radio Tags
# Authors Parsed: ['William E. Gerhard', 'Pratap Tokekar']
# DOI: None
# References: [{'authors': ['J. Linchant', 'J. Lisein', 'J. Semeki', 'P. Lejeune', 'and C. Vermeulen'], 'title': 'Areunmanned aircraft systems (uass) the future of wildlife monitoring? areview of accomplishments and challenges'}, {'authors': ['K. V onehr', 'S. Hilaski', 'B. E. Dunne', 'and J. Ward'], 'title': 'Software deﬁnedradio for direction-ﬁnding in uav wildlife tracking'}, {'authors': ['H. Bayram', 'N. Stefas', 'K. S. Engin', 'and V . Isler'], 'title': 'Tracking wildlifewith multiple uavs: System design, safety and ﬁeld experiments'}, {'authors': ['H. Bayram', 'N. Stefas', 'and V . Isler'], 'title': 'Aerial radio-based telemetryfor tracking wildlife'}, {'authors': ['V . Isler', 'N. Noori', 'P. Plonski', 'A. Renzaglia', 'P. Tokekar', 'and J. Van-\nder Hook'], 'title': 'Finding and tracking targets in the wild: Algorithms andﬁeld deployments'}, {'authors': ['J. Vander Hook', 'P. Tokekar', 'and V . Isler'], 'title': 'Cautious greedy strategyfor bearing-based active localization: Experiments and theoreticalanalysis'}, {'authors': ['P. Tokekar', 'E. Branson', 'J. Vander Hook', 'and V . Isler'], 'title': 'Trackingaquatic invaders: Autonomous robots for monitoring invasive ﬁsh'}, {'authors': ['H. Bayram', 'K. Doddapaneni', 'N. Stefas', 'and V . Isler'], 'title': 'Active lo-calization of vhf collared animals with aerial robots'}, {'authors': ['A. Desrochers', 'J. Tremblay', 'Y . Aubry', 'D. Chabot', 'P. Pace', 'and D. Bird'], 'title': 'Estimating wildlife tag location errors from a vhf receiver mountedon a drone'}, {'authors': ['R. B. MacCurdy', 'R. M. Gabrielson', 'and K. A. Cortopassi'], 'title': 'Automatedwildlife radio tracking'}, {'authors': [], 'title': 'Doppler df instruments : More picodopp df information'}, {'authors': [], 'title': 'Introduction into theory of direction ﬁnding'}, {'authors': [], 'title': 'Hackrf one - great scott gadgets'}, {'authors': [], 'title': 'Opera cake mossmann/hackrf wiki'}, {'authors': ['J. Moell'], 'title': 'Wide-range antenna arrays for the roanoke doppler'}, {'authors': ['A. M ˚arell', 'J. P. Ball', 'and A. Hofgaard'], 'title': 'Foraging and movement pathsof female reindeer: insights from fractal analysis, correlated randomwalks, and l ´evy ﬂights'}, {'authors': ['S. Benhamou'], 'title': 'How many animals really do the l ´evy walk?'}, {'authors': ['F. Bartumeus', 'M. G. E. da Luz', 'G. M. Viswanathan', 'and J. Cata-\nlan'], 'title': 'Animal search strategies: a quantitative random-walk analysis'}, {'authors': ['A. M. Johansen'], 'title': 'Smctc: Sequential monte carlo in c++'}, {'authors': ['J. S. Liu R. Chen'], 'title': 'Sequential monte carlo methods for dynamicsystems'}, {'authors': ['A. Torabi', 'M. W. Shafer', 'G. S. Vega', 'and K. M. Rothfus'], 'title': 'Uav-rt:An sdr based aerial platform for wildlife tracking'}]
# --------------------------------------------------
# 2003.00553.pdf
# Title: Ego-based Entropy Measures for Structural Representations
# Authors Parsed: ['George Dasoulas', 'Giannis Nikolentzos', 'Kevin Scaman', 'Aladin Virmaux', 'Michalis Vazirgiannis']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00485.pdf
# Title: Spin kinetic equations in the probability representation of quantum
#   mechanics
# Authors Parsed: ['Vladimir N. Chernega', "Vladimir I. Man'ko"]
# DOI: 10.1007/s10946-019-09830-3
# References: None
# --------------------------------------------------
# 2003.01122.pdf
# Title: A Semi-Automated Computational Approach for Infrared Dark Cloud
#   Localization: A Catalog of Infrared Dark Clouds
# Authors Parsed: ['Jyothish Pari', 'Joseph L. Hora']
# DOI: 10.1088/1538-3873/ab7b39
# References: None
# --------------------------------------------------
# 2003.00592.pdf
# Title: Sheaves of Higher Categories on Generalised Spaces
# Authors Parsed: ['Severin Bunk']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00748.pdf
# Title: Electronic Decoupling of Polyacenes from the Underlying Metal Substrate
#   by sp3 Carbon Atoms
# Authors Parsed: ['Mohammed S. G. Mohammed', 'Luciano Colazzo', 'Roberto Robles', 'Ruth Dorel', 'Antonio M. Echavarren', 'Nicolás Lorente', 'Dimas G. de Oteyza']
# DOI: 10.1038/s42005-020-00425-y
# References: []
# --------------------------------------------------
# 2003.00358.pdf
# Title: Multiplicities, pictographs, and volumes
# Authors Parsed: ['Robert Coquereaux']
# DOI: 10.1134/S1547477120050118
# References: None
# --------------------------------------------------
# 2003.01702.pdf
# Title: Generalised hydrodynamics with dephasing noise
# Authors Parsed: ['Alvise Bastianello', 'Jacopo De Nardis', 'Andrea De Luca']
# DOI: 10.1103/PhysRevB.102.161110
# References: None
# --------------------------------------------------
# 2003.01472.pdf
# Title: Seshat: A tool for managing and verifying annotation campaigns of audio
#   data
# Authors Parsed: ['Hadrien Titeux', 'Rachid Riad', 'Xuan-Nga Cao', 'Nicolas Hamilakis', 'Kris Madden', 'Alejandrina Cristia', 'Anne-Catherine Bachoud-Lévi', 'Emmanuel Dupoux']
# DOI: None
# References: []
# --------------------------------------------------
# 2003.00904.pdf
# Title: Extensions of Fiedler-Markham's inequality and Thompson's inequality
# Authors Parsed: ['Yongtao Li', 'Yang Huang', 'Lihua Feng', 'Weijun Liu']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01341.pdf
# Title: Protecting an unknown qubit state by weak measurement
# Authors Parsed: ['Ozra Heibati', 'Azam Mani', 'Esfandiar Faizi', 'Vahid Karimipour']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00845.pdf
# Title: Addressing target shift in zero-shot learning using grouped adversarial
#   learning
# Authors Parsed: ['Saneem Ahmed Chemmengath', 'Soumava Paul', 'Samarth Bharadwaj', 'Suranjana Samanta', 'Karthik Sankaranarayanan']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01038.pdf
# Title: Gravitational couplings in Chameleon models
# Authors Parsed: ['Macarena Lagos', 'Hanjue Zhu']
# DOI: 10.1088/1475-7516/2020/06/061
# References: None
# --------------------------------------------------
# 2003.01306.pdf
# Title: Machine Learning Empowered Beam Management for Intelligent Reflecting
#   Surface Assisted MmWave Networks
# Authors Parsed: ['Chenglu Jia', 'Hui Gao', 'Na Chen', 'Yuan He']
# DOI: None
# References: [{'authors': ['T. S. Rappaport', 'S. Sun', 'R. Mayzus', 'H. Zhao', 'Y . Azar', 'K. Wang', 'G. N.\nWong', 'J. K. Schulz', 'M. Samimi', 'and F. Gutierrez'], 'title': 'Millimeter wavemobile communications for 5G cellular: It will work!'}, {'authors': ['M. Giordani', 'M. Polese', 'A. Roy', 'D. Castor', 'and M. Zorzi'], 'title': 'A tutorialon beam management for 3GPP NR at mmwave frequencies'}, {'authors': ['Q. Wu R. Zhang'], 'title': 'Intelligent reﬂecting surface enhanced wirelessnetwork: Joint active and passive beamforming design'}, {'authors': ['C. Huang', 'S. Hu', 'G. Alexandropoulos', 'A. Zappone', 'C. Yuen', 'R. Zhang', 'M. D. Renzo', 'and M. Debbah'], 'title': 'Holographic MIMO surfaces for 6Gwireless networks: Opportunities, challenges, and trends'}, {'authors': ['C. Huang', 'A. Zappone', 'G. Alexandropoulos', 'M. Debbah', 'and C. Yuen'], 'title': 'Reconﬁgurable intelligent surfaces for energy efﬁciency in wirelesscommunication'}, {'authors': ['P. Wang', 'J. Fang', 'X. Yuan', 'Z. Chen', 'H. Duan', 'and H. Li'], 'title': 'Intelligentreﬂecting surface-assisted millimeter wave communications: Joint activeand passive precoding design'}, {'authors': ['G. Zheng', 'C. Hua', 'R. Zheng', 'and Q. Wang'], 'title': 'Toward robust relayplacement in 60 GHz mmwave wireless personal area networks withdirectional antenna'}, {'authors': ['O. Eng', 'J. Kneckt', 'O. Alanen', 'Z. Chang', 'T. Huovinen', 'and T. Nihtil?'], 'title': 'IEEE 802.11ac: Enhancements for very high throughput WLANs'}, {'authors': ['D. De Donno', 'J. Palacios', 'and J. Widmer'], 'title': 'Millimeter-wave beamtraining acceleration through low-complexity hybrid transceivers'}, {'authors': ['J. Aviles A. Kouki'], 'title': 'Position-aided mm-wave beam training underNLOS conditions'}, {'authors': ['V . Va', 'T. Shimizu', 'G. Bansal', 'and R. Heath'], 'title': 'Online learning forposition-aided millimeter wave beam training'}, {'authors': ['S. Jayaprakasam', 'X. Ma', 'J. Choi', 'and S. Kim'], 'title': 'Robust beam-trackingfor mmWave mobile communications'}, {'authors': ['D. Zhu', 'J. Choi', 'Q. Cheng', 'W. Xiao', 'and R. Heath'], 'title': 'High-resolutionangle tracking for mobile wideband millimeter-wave systems withantenna array calibration'}, {'authors': ['J. Zhang', 'W. Xu', 'H. Gao', 'M. Pan', 'Z. Feng', 'and Z. Han'], 'title': 'Position-attitudeprediction based beam tracking for UA V mmWave communications'}, {'authors': ['A. Taha', 'M. Alrabeiah', 'and A. Alkhateeb'], 'title': 'Enabling large intelligentsurfaces with compressive sensing and deep learning'}, {'authors': ['W. Liu Z. Wang'], 'title': 'Statistics-assisted beam training for mmwavemassive MIMO systems'}, {'authors': ['N. Gonz ´alez-Prelcic', 'A. Ali', 'V . Va', 'and R. Heath'], 'title': 'Millimeter-wavecommunication with out-of-band information'}, {'authors': ['M. D. Renzo et al'], 'title': 'Smart radio environments empowered by recon-ﬁgurable AI meta-surfaces: an idea whose time has come'}, {'authors': ['W. Xu', 'Y . Xu', 'C. Lee', 'Z. Feng', 'P. Zhang', 'and J. Lin'], 'title': 'Data-cognition-empowered intelligent wireless networks: Data, utilities, cognition brain,and architecture'}]
# --------------------------------------------------
# 2003.01541.pdf
# Title: Explainable and Scalable Machine-Learning Algorithms for Detection of
#   Autism Spectrum Disorder using fMRI Data
# Authors Parsed: ['Taban Eslami', 'Joseph S. Raiker', 'Fahad Saeed']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00088.pdf
# Title: Data based two-body current contribution to neutrino-nucleus cross
#   section
# Authors Parsed: ['Tomasz Bonus', 'Jan T. Sobczyk', 'Michał Siemaszko', 'Cezary Juszczak']
# DOI: 10.1103/PhysRevC.102.015502
# References: None
# --------------------------------------------------
# 2003.01725.pdf
# Title: MOSEL Survey: Tracking the Growth of Massive Galaxies at 2<z<4 using
#   Kinematics and the IllustrisTNG Simulation
# Authors Parsed: ['Anshu Gupta', 'Kim-Vy Tran', 'Jonathan Cohn', 'Leo Y. Alcorn', 'Tiantian Yuan', 'Vicente Rodriguez-Gomez', 'Anishya Harshan', 'Ben Forrest', 'Lisa J. Kewley', 'Karl Glazebrook', 'Caroline M. Straatman', 'Glenn G. Kacprzak', 'Themiya Nanayakkara', 'Ivo Labbé', 'Casey Papovich', 'Michael Cowley']
# DOI: 10.3847/1538-4357/ab7b6d
# References: None
# --------------------------------------------------
# 2003.00661.pdf
# Title: On Lie algebras of generalized Jacobi matrices
# Authors Parsed: ['Alice Fialowski', 'Kenji Iohara']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01107.pdf
# Title: Reconfigurable Parallel Architecture of High Speed Round Robin Arbiter
# Authors Parsed: ['Arnab Paul', 'Mamdudul Haque Khan', 'M. Muktadir Rahman', 'Tanvir Zaman Khan', 'Prajoy Podder', 'Md. Yeasir Akram Khan']
# DOI: 10.1109/EESCO.2015.7253744
# References: [{'authors': ['E. S. Shin', 'V. J. Mooney  G. F. Riley'], 'title': 'Round -robin Arbiter Design and Generation'}, {'authors': ['M. Abdelrasoul', 'M. Ragab V. Goulart'], 'title': "Impact of Round Robin Arbiters on router's performance for NoCs on FPGAs"}, {'authors': ['Stephen Brown Zvonko Vranesic book'], 'title': 'Fundamentals of Digital Logic with Verilog Design'}, {'authors': ['Yong jian Li', 'Naiju Zeng', 'W. N. N. Hung Xiaoyu Song'], 'title': 'Enhanced symbolic simulation of a round -robin arbiter'}, {'authors': ['Si Qing Zheng Mei Yang'], 'title': 'Algorithm -Hardware Codesign of  Fast Parallel Round -Robin Arbiters'}, {'authors': ['S. Q. Zheng', 'Mei Yang', 'J. Blanton P. Golla'], 'title': 'A simple and fast parallel round -robin arbiter for high -speed switch control and sched uling'}, {'authors': ['Matt Weber'], 'title': 'Arbiters: Design Ideas and Coding Styles'}, {'authors': ['Jinming Ge'], 'title': 'Round -Robin Arbiter Design'}, {'authors': ['K. C. Lee'], 'title': 'A variable round -robin arbiter for high speed buses and statistical multiplexers'}, {'authors': ['N. Sertac  Artan', 'M ing Yang H. Jonathan Chao'], 'title': 'Hierarchical Round Robin Arbiter for High -Speed, Low -Power, a nd Scalable Networks -on-Chip'}]
# --------------------------------------------------
# 2003.00884.pdf
# Title: Cleaner Production in Optimized Multivariate Networks: Operations
#   Management through a Roll of Dice
# ...
# --------------------------------------------------
# 2003.01116.pdf
# Title: International Large Detector: Interim Design Report
# Authors Parsed: [' The ILD Collaboration']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00895.pdf
# Title: Revisiting Convolutional Neural Networks for Citywide Crowd Flow
#   Analytics
# Authors Parsed: ['Yuxuan Liang', 'Kun Ouyang', 'Yiwei Wang', 'Ye Liu', 'Junbo Zhang', 'Yu Zheng', 'David S. Rosenblum']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01356.pdf
# Title: Broadband Tunable Phase Shifter For Microwaves
# Authors Parsed: ['Jinli Zhang', 'Tianyi Li', 'Roope Kokkoniemi', 'Chengyu Yan', 'Wei Liu', 'Matti Partanen', 'Kuan Yen Tan', 'Ming He', 'Lu Ji', 'Leif Grönberg', 'Mikko Möttönen']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.01146.pdf
# Title: Central extensions and bounded cohomology
# Authors Parsed: ['Roberto Frigerio', 'Alessandro Sisto']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00749.pdf
# Title: A general framework for scientifically inspired explanations in AI
# Authors Parsed: ['David Tuckey', 'Alessandra Russo', 'Krysia Broda']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00627.pdf
# Title: Cluster-Based Social Reinforcement Learning
# Authors Parsed: ['Mahak Goindani', 'Jennifer Neville']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00224.pdf
# Title: Seeing through multimode fibers with real-valued intensity transmission
#   matrices
# Authors Parsed: ['Tianrui Zhao', 'Sebastien Ourselin', 'Tom Vercauteren', 'Wenfeng Xia']
# DOI: 10.1364/OE.396734
# References: None
# --------------------------------------------------
# 2003.01340.pdf
# Title: Design of Convergence-Optimized Non-binary LDPC Codes over Binary
#   Erasure Channel
# Authors Parsed: ['Yang Yu', 'Wen Chen', 'Lili Wei']
# DOI: None
# References: [{'authors': ['V . Savin'], 'title': 'Non binary ldpc codes over the binaryerasure channel: density evolution analysis'}, {'authors': ['G. Li', 'I. Fair', 'and W. Krzymien'], 'title': 'Density evolution for no nbinary ldpccodes under gaussian approximation'}, {'authors': ['A. E. Ashikhmin', 'G. Kramer', 'and S. ten Brink'], 'title': 'Extrinsic i nformationtransfer functions: model and erasure channel properties,'}, {'authors': ['V . Savin'], 'title': 'Binary linear-time erasure decoding for non- binary ldpc codes'}, {'authors': ['R. Lidl', 'Introduction to ﬁnite ﬁelds their applications. Cambridge', '2002.\n[6] X. Ma B. Bai'], 'title': 'A uniﬁed decoding algorithm for linear c odes basedon partitioned parity-check matrices'}, {'authors': ['M. Luby', 'M. Mitzenmacher', 'M. A. Shokrollahi', 'D. A. Spielm an', 'and\nV . Stemann'], 'title': 'Practical loss-resilient codes.'}, {'authors': ['B. Smith', 'M. Ardakani', 'W. Yu', 'and F. Kschischang'], 'title': 'Design of irreg-ular ldpc codes with optimized performance-complexity tra deoff'}]
# --------------------------------------------------
# 2003.01554.pdf
# Title: Underactuated Waypoint Trajectory Optimization for Light Painting
#   Photography
# Authors Parsed: ['Christian Eilers', 'Jonas Eschmann', 'Robin Menzenbach', 'Boris Belousov', 'Fabio Muratore', 'Jan Peters']
# DOI: None
# References: [{'authors': ['M. W. Spong'], 'title': 'Underactuated mechanical systems'}, {'authors': ['H. M. Choset', 'S. Hutchinson', 'K. M. Lynch', 'G. Kantor', 'W. Burgard', 'L. E. Kavraki', 'and S. Thrun', 'Principles of robot motion: theory', 'algorithms', 'and implementation . MIT press', '2005.\n[3] R. Tedrake. Underactuated robotics: Algorithms for walking', 'running', 'swimming', 'ﬂying', 'and manipulation (course notes for MIT 6.832).\n[Online]. Available: http://underactuated.mit.edu/\n[4] M. W. Spong'], 'title': 'Partial feedback linearization of underactuated mechan-ical systems'}, {'authors': ['I. Fantoni R. Lozano', 'Non-linear control for underactuated\nmechanical systems . Springer Science & Business Media', '2001.\n[6] J. Lin', 'N. Somani', 'B. Hu', 'M. Rickert', 'and A. Knoll'], 'title': 'An efﬁcientand time-optimal trajectory generation approach for waypoints underkinematic constraints and error bounds'}, {'authors': ['J. Schultz T. Murphey'], 'title': 'Trajectory generation for underactuatedcontrol of a suspended mass'}, {'authors': ['K. Furuta', 'M. Yamakita', 'and S. Kobayashi'], 'title': 'Swing-up control ofinverted pendulum using pseudo-state feedback'}, {'authors': ['B. S. Cazzolato Z. Prime'], 'title': 'On the dynamics of the furutapendulum'}, {'authors': ['J. T. Betts'], 'title': 'Survey of numerical methods for trajectory optimization'}, {'authors': ['C. R. Hargraves S. W. Paris'], 'title': 'Direct trajectory optimizationusing nonlinear programming and collocation'}, {'authors': ['J. A. E. Andersson', 'J. Gillis', 'G. Horn', 'J. B. Rawlings', 'and M. Diehl'], 'title': 'CasADi – A software framework for nonlinear optimization andoptimal control'}, {'authors': ['F. L. Lewis', 'D. Vrabie', 'and V . L. Syrmos', 'Optimal control . John\nWiley & Sons', '2012.\n[14] A. W. Divelbiss J. T. Wen'], 'title': 'Trajectory tracking control of a car-trailer system'}, {'authors': ['A. Marco', 'P. Hennig', 'J. Bohg', 'S. Schaal', 'and S. Trimpe'], 'title': 'Automaticlqr tuning based on gaussian process global optimization'}, {'authors': ['Quanser Inc.'], 'title': 'Qube-servo 2 workbook - student version'}]
# --------------------------------------------------
# 2003.00681.pdf
# Title: Fixed points for group actions on 2-dimensional affine buildings
# Authors Parsed: ['Jeroen Schillewaert', 'Koen Struyve', 'Anne Thomas']
# DOI: None
# References: None
# --------------------------------------------------
# 2003.00272.pdf
# Title: Wavebreaking amplitudes in warm, inhomogeneous plasmas revisited
# Authors Parsed: ['Nidhi Rathee', 'Arghya Mukherjee', 'R. M. G. M. Trines', 'Sudip Sengupta']
# DOI: 10.1063/5.0033658
# References: None
# --------------------------------------------------
# 2003.01330.pdf
# Title: Diederich-Fornaess and Steinness indices for abstract CR manifolds
# Authors Parsed: ['Masanori Adachi', 'Jihun Yum']
# DOI: 10.1007/s12220-020-00598-6
# References: None
# --------------------------------------------------
# 2003.00255.pdf
# Title: Joint Face Completion and Super-resolution using Multi-scale Feature
#   Relation Learning
# Authors Parsed: ['Zhilei Liu', 'Yunpeng Wu', 'Le Li', 'Cuicui Zhang', 'Baoyuan Wu']
# DOI: None
# References: None
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 159
#     153 raw_data_folder = "../Raw_data"
#     156 json_file_path = "../arxiv_metadata_dump//arxiv-metadata-oai-snapshot.json"
# --> 159 data_dict = process_remaining_pdfs(raw_data_folder, json_file_path)
#
# Cell In[43], line 119, in process_remaining_pdfs(raw_data_folder, json_file_path)
#     114 pdf_filename = os.path.splitext(pdf_file)[0][:-2]+".pdf"
#     117 if pdf_filename in pdf_metadata_dict:
# --> 119     references = extract_information(pdf_file)
#     122     metadata = pdf_metadata_dict[pdf_filename]
#     123     title = metadata['title']
#
# Cell In[43], line 64, in extract_information(pdf_file)
#      62 for page_num in range(len(pdf_reader.pages)):
#      63     page = pdf_reader.pages[page_num]
# ---> 64     text = page.extract_text()
#      67     references = extract_references(text)
#      70 file.close()
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/_page.py:1851, in PageObject.extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1848 if isinstance(orientations, int):
#    1849     orientations = (orientations,)
# -> 1851 return self._extract_text(
#    1852     self,
#    1853     self.pdf,
#    1854     orientations,
#    1855     space_width,
#    1856     PG.CONTENTS,
#    1857     visitor_operand_before,
#    1858     visitor_operand_after,
#    1859     visitor_text,
#    1860 )
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/_page.py:1737, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1734 xobj = resources_dict["/XObject"]
#    1735 if xobj[operands[0]]["/Subtype"] != "/Image":  # type: ignore
#    1736     # output += text
# -> 1737     text = self.extract_xform_text(
#    1738         xobj[operands[0]],  # type: ignore
#    1739         orientations,
#    1740         space_width,
#    1741         visitor_operand_before,
#    1742         visitor_operand_after,
#    1743         visitor_text,
#    1744     )
#    1745     output += text
#    1746     if visitor_text is not None:
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/_page.py:1880, in PageObject.extract_xform_text(self, xform, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text)
#    1862 def extract_xform_text(
#    1863     self,
#    1864     xform: EncodedStreamObject,
#    (...)
#    1869     visitor_text: Optional[Callable[[Any, Any, Any, Any, Any], None]] = None,
#    1870 ) -> str:
#    1871     """
#    1872     Extract text from an XObject.
#    1873
#    (...)
#    1878         The extracted text
#    1879     """
# -> 1880     return self._extract_text(
#    1881         xform,
#    1882         self.pdf,
#    1883         orientations,
#    1884         space_width,
#    1885         None,
#    1886         visitor_operand_before,
#    1887         visitor_operand_after,
#    1888         visitor_text,
#    1889     )
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/_page.py:1356, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1352     content = (
#    1353         obj[content_key].get_object() if isinstance(content_key, str) else obj
#    1354     )
#    1355     if not isinstance(content, ContentStream):
# -> 1356         content = ContentStream(content, pdf, "bytes")
#    1357 except KeyError:  # it means no content can be extracted(certainly empty page)
#    1358     return ""
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/generic/_data_structures.py:877, in ContentStream.__init__(self, stream, pdf, forced_encoding)
#     875     stream_bytes = BytesIO(stream_data_bytes)
#     876 self.forced_encoding = forced_encoding
# --> 877 self.__parse_content_stream(stream_bytes)
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/generic/_data_structures.py:943, in ContentStream.__parse_content_stream(self, stream)
#     941         peek = stream.read(1)
#     942 else:
# --> 943     operands.append(read_object(stream, None, self.forced_encoding))
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/generic/_data_structures.py:1077, in read_object(stream, pdf, forced_encoding)
#    1075         return IndirectObject.read_from_stream(stream, pdf)
#    1076     else:
# -> 1077         return NumberObject.read_from_stream(stream)
#    1078 else:
#    1079     stream.seek(-20, 1)
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/generic/_base.py:407, in NumberObject.read_from_stream(stream)
#     405 num = read_until_regex(stream, NumberObject.NumberPattern)
#     406 if num.find(b".") != -1:
# --> 407     return FloatObject(num)
#     408 return NumberObject(num)
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/generic/_base.py:330, in FloatObject.__new__(cls, value, context)
#     326 def __new__(
#     327     cls, value: Union[str, Any] = "0", context: Optional[Any] = None
#     328 ) -> "FloatObject":
#     329     try:
# --> 330         return decimal.Decimal.__new__(cls, str_(value), context)
#     331     except Exception:
#     332         # If this isn't a valid decimal (happens in malformed PDFs)
#     333         # fallback to 0
#     334         logger_warning(f"FloatObject ({value}) invalid; use 0.0 instead", __name__)
#
# File ~/.local/lib/python3.10/site-packages/PyPDF2/_utils.py:290, in str_(b)
#     285 @overload
#     286 def str_(b: bytes) -> str:
#     287     ...
# --> 290 def str_(b: Union[str, bytes]) -> str:
#     291     if isinstance(b, bytes):
#     292         return b.decode("latin-1")
#
# KeyboardInterrupt:
